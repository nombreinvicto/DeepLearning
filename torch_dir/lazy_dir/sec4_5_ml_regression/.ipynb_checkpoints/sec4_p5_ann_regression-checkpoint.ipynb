# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.figure import Figure
from matplotlib.axes import Axes
from mpl_toolkits.mplot3d import Axes3D

sns.set()

# %%
import torch
from torch import nn
from torch import optim

# %%
# make dataset
N = 1000
# random gives random floats in the half interval [0-1]
# x is 1000 x 2. First column is x1, second is x2
x = np.random.random((N, 2)) * 6 - 3  # shift interval to [-3, +3]

# %%
# make the y
# we have 3 variables, x1, x2 and y hence its a 3d plot
y = np.cos(2 * x[:, 0]) + np.cos(3 * x[:, 1])

# %%
# plot the graph
fig = plt.figure() # type: Figure
ax = fig.add_subplot(111, projection="3d") # type: Axes3D
ax.scatter(x[:,0], x[:,1], y)
ax.set_xlabel("x1")
ax.set_ylabel("x2")
ax.set_zlabel("y")
# Out:
# Text(0.5, 0, 'y')

# %%
# build the model with inputs x1, x2 and output y
model = nn.Sequential(
    nn.Linear(in_features=2, out_features=128),
    nn.ReLU(),
    nn.Linear(in_features=128, out_features=1)

)

# %%
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=0.01)

# %%
# train the model
xtrain = torch.from_numpy(x.astype(np.float32))
ytrain = torch.from_numpy(y.astype(np.float32)).reshape(-1, 1)

epochs = 1000
train_losses = np.zeros(epochs)

for i in range(epochs):
    # zero the optimizer
    optimizer.zero_grad()

    # forward pass
    outputs = model(xtrain)
    loss = criterion(outputs, ytrain)

    # backward step
    loss.backward()
    optimizer.step()

    train_losses[i] = loss.item()

    if (i+1)%10 == 0:
        print(f"[INFO] epoch: {i+1} with train_loss: {loss.item()}......")
# Out:
# [INFO] epoch: 10 with train_loss: 0.8923155665397644......
# [INFO] epoch: 20 with train_loss: 0.8319955468177795......
# [INFO] epoch: 30 with train_loss: 0.766117513179779......
# [INFO] epoch: 40 with train_loss: 0.6836671233177185......
# [INFO] epoch: 50 with train_loss: 0.586389422416687......
# [INFO] epoch: 60 with train_loss: 0.488747775554657......
# [INFO] epoch: 70 with train_loss: 0.4023202955722809......
# [INFO] epoch: 80 with train_loss: 0.3323303163051605......
# [INFO] epoch: 90 with train_loss: 0.29164716601371765......
# [INFO] epoch: 100 with train_loss: 0.25163066387176514......
# [INFO] epoch: 110 with train_loss: 0.22560274600982666......
# [INFO] epoch: 120 with train_loss: 0.1971094012260437......
# [INFO] epoch: 130 with train_loss: 0.1669325828552246......
# [INFO] epoch: 140 with train_loss: 0.1367543637752533......
# [INFO] epoch: 150 with train_loss: 0.1085987463593483......
# [INFO] epoch: 160 with train_loss: 0.08476974815130234......
# [INFO] epoch: 170 with train_loss: 0.0710550919175148......
# [INFO] epoch: 180 with train_loss: 0.05386928841471672......
# [INFO] epoch: 190 with train_loss: 0.043308861553668976......
# [INFO] epoch: 200 with train_loss: 0.034299153834581375......
# [INFO] epoch: 210 with train_loss: 0.027672605589032173......
# [INFO] epoch: 220 with train_loss: 0.022335758432745934......
# [INFO] epoch: 230 with train_loss: 0.018650611862540245......
# [INFO] epoch: 240 with train_loss: 0.01877679117023945......
# [INFO] epoch: 250 with train_loss: 0.01570751704275608......
# [INFO] epoch: 260 with train_loss: 0.01233894843608141......
# [INFO] epoch: 270 with train_loss: 0.010454951785504818......
# [INFO] epoch: 280 with train_loss: 0.00942896492779255......
# [INFO] epoch: 290 with train_loss: 0.00848318636417389......
# [INFO] epoch: 790 with train_loss: 0.0029481779783964157......
# [INFO] epoch: 800 with train_loss: 0.002930414630100131......
# [INFO] epoch: 810 with train_loss: 0.0029118789825588465......
# [INFO] epoch: 820 with train_loss: 0.002894324017688632......
# [INFO] epoch: 830 with train_loss: 0.0028768612537533045......
# [INFO] epoch: 840 with train_loss: 0.002871727105230093......
# [INFO] epoch: 850 with train_loss: 0.0042720516212284565......
# [INFO] epoch: 860 with train_loss: 0.0037381560541689396......
# [INFO] epoch: 870 with train_loss: 0.003335522720590234......
# [INFO] epoch: 880 with train_loss: 0.002903805812820792......
# [INFO] epoch: 890 with train_loss: 0.003358438378199935......
# [INFO] epoch: 900 with train_loss: 0.01148634497076273......
# [INFO] epoch: 910 with train_loss: 0.006008166819810867......
# [INFO] epoch: 920 with train_loss: 0.0037067129742354155......
# [INFO] epoch: 930 with train_loss: 0.0028177781496196985......
# [INFO] epoch: 940 with train_loss: 0.002699602860957384......
# [INFO] epoch: 950 with train_loss: 0.002687609288841486......
# [INFO] epoch: 960 with train_loss: 0.0026920505333691835......
# [INFO] epoch: 970 with train_loss: 0.0026414222083985806......
# [INFO] epoch: 980 with train_loss: 0.002649902831763029......
# [INFO] epoch: 990 with train_loss: 0.0031070392578840256......
# [INFO] epoch: 1000 with train_loss: 0.016122039407491684......

# %%
f, ax = plt.subplots(1,1, figsize=(12, 8)) # type: Figure, Axes
sns.lineplot(x=np.arange(epochs)+1, y=train_losses, ax=ax, color="green",linewidth=2)
ax.set_xlabel("Epochs")
ax.set_ylabel("Loss");

# %%
# plot the actual points in 3d
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(x[:,0], x[:,1], y, color="red")

# now plot the prediction surface
with torch.no_grad():
    line = np.linspace(-3, 3, 50) # generate 50 data points in the range [-3, 3] remember our x1 and x2 are in that range
    x1, x2 = np.meshgrid(line, line)

    # x1 and x2 are as grids. need to convert them into data format the model expectsas N X 2 matrix
    x_grid = np.vstack((x1.flatten(), x2.flatten())).T
    x_torch = torch.from_numpy(x_grid.astype(np.float32))
    yhat = model(x_torch).numpy().flatten()
    ax.plot_trisurf(x_grid[:,0], x_grid[:,1], yhat, linewidth=0.2, antialiased=True)
    plt.show()

# %% [markdown]
# The neural network manages to approximate the non linear function quite well using just linear layers and some non linearity.

# %%
# can it extrapolate beyond the [-3, 3] data range across each axis dince the curve looks like a sinusoid that repeats?

# plot the actual points in 3d
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(x[:,0], x[:,1], y, color="green")

# now plot the prediction surface
with torch.no_grad():
    line = np.linspace(-5, 5, 50) # generate 50 data points in the range [-3, 3] remember our x1 and x2 are in that range
    x1, x2 = np.meshgrid(line, line)

    # x1 and x2 are as grids. need to convert them into data format the model expectsas N X 2 matrix
    x_grid = np.vstack((x1.flatten(), x2.flatten())).T
    x_torch = torch.from_numpy(x_grid.astype(np.float32))
    yhat = model(x_torch).numpy().flatten()
    ax.plot_trisurf(x_grid[:,0], x_grid[:,1], yhat, linewidth=0.2, antialiased=True)
    plt.show()

# %% [markdown]
# It doesnt quite work now and it assumes the pattern keeps going the direction its going at the edges. This is because the NN doesnt use a periodic activation function and hence we cant expect its output to be periodic wrt its inputs.
