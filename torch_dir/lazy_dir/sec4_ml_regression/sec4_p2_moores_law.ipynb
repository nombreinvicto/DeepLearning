# %%
import sys, os, json
import numpy as np
import pandas as pd
import seaborn as sns
import argparse
import matplotlib.pyplot as plt
from matplotlib.figure import Figure
from matplotlib.axes import Axes

sns.set()

# %%
import torch
from torch import nn
from torch import optim
import torch.nn.functional as F
from torch.utils.data import DataLoader
from torchvision import datasets, transforms, models

# %%
cwd = os.getcwd()
data_path = os.path.sep.join([cwd, 'moore.csv'])
data = pd.read_csv(data_path, header=None).values

# %%
# get x's and y's for plotting and everything else
# reshaping into 2D for Pytorch
x = data[:, 0].reshape(-1, 1)
y = data[:, 1].reshape(-1, 1)

# %%
# plot the scatterplot
plt.scatter(x,y)

# %%
# lets take log of Y i.e log C to see how it varies with t

log_y = np.log(y)
plt.scatter(x=x, y=log_y)

# %%
# standardise the x's and y's

mx = x.mean()
sx = x.std()

my = log_y.mean()
sy = log_y.std()

# standardise
X = (x - mx) / sx
Y = (log_y - my) / sy

plt.scatter(X, Y)

# %%
#preprocess for pytorch model

inputs = torch.from_numpy(X.astype(np.float32))
targets = torch.from_numpy(Y.astype(np.float32))

# %%
# model architecture
model = nn.Linear(in_features=1, out_features=1)

# %%
# criterion and optimizer
criterion = nn.MSELoss()
optimizer = optim.SGD(model.parameters(), lr=0.01, momentum=0.7)

# %%
# train the model
epochs = 100
avg_losses_per_batch = []

for i in range(epochs):
    # zero grad the optimizer
    optimizer.zero_grad()

    outputs = model(inputs)
    loss = criterion(outputs, targets)
    avg_losses_per_batch.append(loss.item())

    # backward step
    loss.backward()
    optimizer.step()
    
    print(f"[INFO] epoch: {i+1} / {epochs} with loss: {loss.item()}......")
# Out:
# [INFO] epoch: 1 / 100 with loss: 2.4933722019195557......
# [INFO] epoch: 2 / 100 with loss: 2.396158218383789......
# [INFO] epoch: 3 / 100 with loss: 2.237260341644287......
# [INFO] epoch: 4 / 100 with loss: 2.0444440841674805......
# [INFO] epoch: 5 / 100 with loss: 1.8379377126693726......
# [INFO] epoch: 6 / 100 with loss: 1.6316099166870117......
# [INFO] epoch: 7 / 100 with loss: 1.4343663454055786......
# [INFO] epoch: 8 / 100 with loss: 1.2514421939849854......
# [INFO] epoch: 9 / 100 with loss: 1.085473656654358......
# [INFO] epoch: 10 / 100 with loss: 0.9373349547386169......
# [INFO] epoch: 11 / 100 with loss: 0.8067582845687866......
# [INFO] epoch: 12 / 100 with loss: 0.6927816867828369......
# [INFO] epoch: 13 / 100 with loss: 0.5940616130828857......
# [INFO] epoch: 14 / 100 with loss: 0.5090828537940979......
# [INFO] epoch: 15 / 100 with loss: 0.4362964928150177......
# [INFO] epoch: 16 / 100 with loss: 0.3742050230503082......
# [INFO] epoch: 17 / 100 with loss: 0.32141152024269104......
# [INFO] epoch: 18 / 100 with loss: 0.2766450345516205......
# [INFO] epoch: 19 / 100 with loss: 0.23876941204071045......
# [INFO] epoch: 20 / 100 with loss: 0.206782728433609......
# [INFO] epoch: 21 / 100 with loss: 0.17981034517288208......
# [INFO] epoch: 22 / 100 with loss: 0.1570948362350464......
# [INFO] epoch: 67 / 100 with loss: 0.03852019086480141......
# [INFO] epoch: 68 / 100 with loss: 0.038513679057359695......
# [INFO] epoch: 69 / 100 with loss: 0.038508232682943344......
# [INFO] epoch: 70 / 100 with loss: 0.03850366920232773......
# [INFO] epoch: 71 / 100 with loss: 0.0384998545050621......
# [INFO] epoch: 72 / 100 with loss: 0.03849666193127632......
# [INFO] epoch: 73 / 100 with loss: 0.038493990898132324......
# [INFO] epoch: 74 / 100 with loss: 0.03849175572395325......
# [INFO] epoch: 75 / 100 with loss: 0.03848988190293312......
# [INFO] epoch: 76 / 100 with loss: 0.03848831355571747......
# [INFO] epoch: 77 / 100 with loss: 0.03848700597882271......
# [INFO] epoch: 78 / 100 with loss: 0.03848590329289436......
# [INFO] epoch: 79 / 100 with loss: 0.03848498687148094......
# [INFO] epoch: 80 / 100 with loss: 0.03848421573638916......
# [INFO] epoch: 81 / 100 with loss: 0.038483571261167526......
# [INFO] epoch: 82 / 100 with loss: 0.038483038544654846......
# [INFO] epoch: 83 / 100 with loss: 0.03848258778452873......
# [INFO] epoch: 84 / 100 with loss: 0.03848220780491829......
# [INFO] epoch: 85 / 100 with loss: 0.03848189115524292......
# [INFO] epoch: 86 / 100 with loss: 0.03848163038492203......
# [INFO] epoch: 87 / 100 with loss: 0.03848141059279442......
# [INFO] epoch: 88 / 100 with loss: 0.0384812206029892......
# [INFO] epoch: 89 / 100 with loss: 0.03848107159137726......
# [INFO] epoch: 90 / 100 with loss: 0.03848094120621681......
# [INFO] epoch: 91 / 100 with loss: 0.03848083317279816......
# [INFO] epoch: 92 / 100 with loss: 0.0384807363152504......
# [INFO] epoch: 93 / 100 with loss: 0.03848065808415413......
# [INFO] epoch: 94 / 100 with loss: 0.038480598479509354......
# [INFO] epoch: 95 / 100 with loss: 0.03848054260015488......
# [INFO] epoch: 96 / 100 with loss: 0.038480497896671295......
# [INFO] epoch: 97 / 100 with loss: 0.038480471819639206......
# [INFO] epoch: 98 / 100 with loss: 0.03848044201731682......
# [INFO] epoch: 99 / 100 with loss: 0.03848040848970413......
# [INFO] epoch: 100 / 100 with loss: 0.03848038613796234......

# %%
# plot the loss
plt.scatter(y = avg_losses_per_batch, x = range(epochs))

# %%
# plot the estimated model on overlaid on the data
sns.set(font_scale=1)
predicted_log_y = model(inputs).detach().numpy()
f, ax = plt.subplots(1, 1, figsize=(12, 6)) # type: Figure, Axes
sns.scatterplot(x=X.ravel(), y=Y.ravel(), ax=ax, color = "green", label = "actual")
sns.lineplot(x=X.ravel(), y=predicted_log_y.ravel(), ax=ax, color="red",label="predicted line")
ax.set_xlabel("t_standardised")
ax.set_ylabel("logC_standardised")
plt.setp(ax.get_legend().get_texts(), fontsize='18'); # for legend text

# %%
# get the trained weights of the model
w = model.weight.data.numpy() # slope
b = model.bias.data
