# %%
import os, sys
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.figure import Figure
import matplotlib.axes._axes as axes
sns.set()

# %%
# import scoring and utility functions from sklearn
from sklearn.model_selection import train_test_split, GridSearchCV, learning_curve, ShuffleSplit
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics import f1_score, make_scorer
from sklearn.preprocessing import MinMaxScaler
from sklearn.datasets import make_blobs
from sklearn.impute import SimpleImputer
#
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.svm import SVC

# %%
cwd = os.getcwd()
mood_data = pd.read_csv(f"moodring_data_v2.csv")
mood_data.drop(['Patient_ID', 'week_num'], axis=1, inplace=True)
mood_data.replace([np.inf, -np.inf], np.nan, inplace=True)
mood_data.head()
# Out:
#    ar_daily_mostcommonactivity  ar_daily_sumstationary  ar_daily_sumvehicle  \
# 0                          NaN                     NaN                  NaN
# 1                          NaN                     NaN                  NaN
# 2                          NaN                     NaN                  NaN
# 3                          NaN                     NaN                  NaN
# 4                          NaN                     NaN                  NaN
#
#    ar_daily_summobile  ar_daily_activitychangecount  ar_daily_count  \
# 0                 NaN                           NaN             NaN
# 1                 NaN                           NaN             NaN
# 2                 NaN                           NaN             NaN
# 3                 NaN                           NaN             NaN
# 4                 NaN                           NaN             NaN
#
#    ar_daily_countuniqueactivities  call_incoming_daily_count  \
# 0                             NaN                        NaN
# 1                             NaN                        NaN
# 2                             NaN                        NaN
# 3                             NaN                        NaN
# 4                             NaN                        NaN
#
#    call_incoming_daily_distinctcontacts  call_incoming_daily_meanduration  \
# 0                                   NaN                               NaN
# 1                                   NaN                               NaN
# 2                                   NaN                               NaN
# 3                                   NaN                               NaN
# 4                                   NaN                               NaN
#
#    ...  screen_daily_avgdurationunlock  \
# 0  ...                             NaN
# 1  ...                             NaN
# 2  ...                             NaN
# 3  ...                             NaN
# 4  ...                             NaN
#
#    screen_daily_episodepersensedminutesunlock  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#    screen_daily_firstuseafter00unlock  screen_daily_stddurationunlock  \
# 0                                 NaN                             NaN
# 1                                 NaN                             NaN
# 2                                 NaN                             NaN
# 3                                 NaN                             NaN
# 4                                 NaN                             NaN
#
#    screen_daily_maxdurationunlock  screen_daily_sumdurationunlock  \
# 0                             NaN                             NaN
# 1                             NaN                             NaN
# 2                             NaN                             NaN
# 3                             NaN                             NaN
# 4                             NaN                             NaN
#
#    screen_daily_mindurationunlock  wifi_daily_countscans  \
# 0                             NaN            1266.571429
# 1                             NaN            1161.428571
# 2                             NaN            1233.285714
# 3                             NaN             859.000000
# 4                             NaN            1389.857143
#
#    wifi_daily_uniquedevices  wifi_daily_countscansmostuniquedevice
# 0                  2.571429                             825.142857
# 1                  3.142857                             661.571429
# 2                  2.285714                             599.571429
# 3                  2.428571                             221.857143
# 4                  2.857143                            1109.857143
#
# [5 rows x 111 columns]

# %%
mood_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 462 entries, 0 to 461
# Columns: 111 entries, ar_daily_mostcommonactivity to wifi_daily_countscansmostuniquedevice
# dtypes: float64(111)
# memory usage: 400.8 KB

# %%
# remove any col with > 60% missing data

cols_to_drop = []
total_rows = mood_data.shape[0]
for col in mood_data.columns:
    if mood_data[col].isna().sum() >= 0.6 * total_rows:
        cols_to_drop.append(col)

# %%
new_df = mood_data.drop(columns=cols_to_drop)
new_df.shape
# Out:
# (462, 67)

# %%
new_df[new_df.isnull().any(axis=1)]
# Out:
#      ar_daily_mostcommonactivity  ar_daily_sumstationary  ar_daily_sumvehicle  \
# 0                            NaN                     NaN                  NaN
# 1                            NaN                     NaN                  NaN
# 2                            NaN                     NaN                  NaN
# 3                            NaN                     NaN                  NaN
# 4                            NaN                     NaN                  NaN
# ..                           ...                     ...                  ...
# 457                  1389.714286                     3.0             3.571429
# 458                  1277.428571                     3.0             3.571429
# 459                  1367.142857                     3.0             3.285714
# 460                  1376.857143                     3.0             3.714286
# 461                  1013.500000                     3.0             3.000000
#
#      ar_daily_summobile  ar_daily_activitychangecount  ar_daily_count  \
# 0                   NaN                           NaN             NaN
# 1                   NaN                           NaN             NaN
# 2                   NaN                           NaN             NaN
# 3                   NaN                           NaN             NaN
# 4                   NaN                           NaN             NaN
# ..                  ...                           ...             ...
# 457          153.000000                   1114.833957       74.751526
# 458          156.571429                   1183.589995       76.669657
# 459          169.857143                   1163.327529       53.040324
# 460          169.571429                   1174.505752       61.477840
# 461          110.750000                    967.072813       34.215133
#
#      ar_daily_countuniqueactivities  call_incoming_daily_count  \
# 0                               NaN                        NaN
# 1                               NaN                        NaN
# 2                               NaN                        NaN
# 3                               NaN                        NaN
# 4                               NaN                        NaN
# ..                              ...                        ...
# 457                      125.183269                   0.571429
# 458                       63.663386                        NaN
# 459                      103.707043                   0.428571
# 460                       89.215538                   0.285714
# 461                       59.974483                        NaN
#
#      call_incoming_daily_distinctcontacts  call_incoming_daily_meanduration  \
# 0                                     NaN                               NaN
# 1                                     NaN                               NaN
# 2                                     NaN                               NaN
# 3                                     NaN                               NaN
# 4                                     NaN                               NaN
# ..                                    ...                               ...
# 457                              0.571429                         72.357143
# 458                                   NaN                               NaN
# 459                              0.428571                         17.428571
# 460                              0.285714                          5.571429
# 461                                   NaN                               NaN
#
#      ...  screen_daily_avgdurationunlock  \
# 0    ...                             NaN
# 1    ...                             NaN
# 2    ...                             NaN
# 3    ...                             NaN
# 4    ...                             NaN
# ..   ...                             ...
# 457  ...                             NaN
# 458  ...                             NaN
# 459  ...                             NaN
# 460  ...                             NaN
# 461  ...                             NaN
#
#      screen_daily_episodepersensedminutesunlock  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# ..                                          ...
# 457                                         NaN
# 458                                         NaN
# 459                                         NaN
# 460                                         NaN
# 461                                         NaN
#
#      screen_daily_firstuseafter00unlock  screen_daily_stddurationunlock  \
# 0                                   NaN                             NaN
# 1                                   NaN                             NaN
# 2                                   NaN                             NaN
# 3                                   NaN                             NaN
# 4                                   NaN                             NaN
# ..                                  ...                             ...
# 457                                 NaN                             NaN
# 458                                 NaN                             NaN
# 459                                 NaN                             NaN
# 460                                 NaN                             NaN
# 461                                 NaN                             NaN
#
#      screen_daily_maxdurationunlock  screen_daily_sumdurationunlock  \
# 0                               NaN                             NaN
# 1                               NaN                             NaN
# 2                               NaN                             NaN
# 3                               NaN                             NaN
# 4                               NaN                             NaN
# ..                              ...                             ...
# 457                             NaN                             NaN
# 458                             NaN                             NaN
# 459                             NaN                             NaN
# 460                             NaN                             NaN
# 461                             NaN                             NaN
#
#      screen_daily_mindurationunlock  wifi_daily_countscans  \
# 0                               NaN            1266.571429
# 1                               NaN            1161.428571
# 2                               NaN            1233.285714
# 3                               NaN             859.000000
# 4                               NaN            1389.857143
# ..                              ...                    ...
# 457                             NaN                    NaN
# 458                             NaN                    NaN
# 459                             NaN                    NaN
# 460                             NaN                    NaN
# 461                             NaN                    NaN
#
#      wifi_daily_uniquedevices  wifi_daily_countscansmostuniquedevice
# 0                    2.571429                             825.142857
# 1                    3.142857                             661.571429
# 2                    2.285714                             599.571429
# 3                    2.428571                             221.857143
# 4                    2.857143                            1109.857143
# ..                        ...                                    ...
# 457                       NaN                                    NaN
# 458                       NaN                                    NaN
# 459                       NaN                                    NaN
# 460                       NaN                                    NaN
# 461                       NaN                                    NaN
#
# [412 rows x 67 columns]

# %%
def impute_data(data, strategy):
    imputer = SimpleImputer(strategy=strategy)
    return imputer.fit_transform(data)

# %%
imputed_df = impute_data(new_df, 'median')

# %%
imputed_df = pd.DataFrame(data=imputed_df, columns=new_df.columns)
imputed_df.head()
# Out:
#    ar_daily_mostcommonactivity  ar_daily_sumstationary  ar_daily_sumvehicle  \
# 0                  1502.928572                     3.0                  3.0
# 1                  1502.928572                     3.0                  3.0
# 2                  1502.928572                     3.0                  3.0
# 3                  1502.928572                     3.0                  3.0
# 4                  1502.928572                     3.0                  3.0
#
#    ar_daily_summobile  ar_daily_activitychangecount  ar_daily_count  \
# 0          193.357143                   1031.864848       87.484143
# 1          193.357143                   1031.864848       87.484143
# 2          193.357143                   1031.864848       87.484143
# 3          193.357143                   1031.864848       87.484143
# 4          193.357143                   1031.864848       87.484143
#
#    ar_daily_countuniqueactivities  call_incoming_daily_count  \
# 0                       26.649598                   0.857143
# 1                       26.649598                   0.857143
# 2                       26.649598                   0.857143
# 3                       26.649598                   0.857143
# 4                       26.649598                   0.857143
#
#    call_incoming_daily_distinctcontacts  call_incoming_daily_meanduration  \
# 0                              0.714286                        106.021645
# 1                              0.714286                        106.021645
# 2                              0.714286                        106.021645
# 3                              0.714286                        106.021645
# 4                              0.714286                        106.021645
#
#    ...  screen_daily_avgdurationunlock  \
# 0  ...                        0.176618
# 1  ...                        0.176618
# 2  ...                        0.176618
# 3  ...                        0.176618
# 4  ...                        0.176618
#
#    screen_daily_episodepersensedminutesunlock  \
# 0                                  363.254831
# 1                                  363.254831
# 2                                  363.254831
# 3                                  363.254831
# 4                                  363.254831
#
#    screen_daily_firstuseafter00unlock  screen_daily_stddurationunlock  \
# 0                           76.395068                        0.039294
# 1                           76.395068                        0.039294
# 2                           76.395068                        0.039294
# 3                           76.395068                        0.039294
# 4                           76.395068                        0.039294
#
#    screen_daily_maxdurationunlock  screen_daily_sumdurationunlock  \
# 0                         6.56352                       13.603958
# 1                         6.56352                       13.603958
# 2                         6.56352                       13.603958
# 3                         6.56352                       13.603958
# 4                         6.56352                       13.603958
#
#    screen_daily_mindurationunlock  wifi_daily_countscans  \
# 0                       183.13006            1266.571429
# 1                       183.13006            1161.428571
# 2                       183.13006            1233.285714
# 3                       183.13006             859.000000
# 4                       183.13006            1389.857143
#
#    wifi_daily_uniquedevices  wifi_daily_countscansmostuniquedevice
# 0                  2.571429                             825.142857
# 1                  3.142857                             661.571429
# 2                  2.285714                             599.571429
# 3                  2.428571                             221.857143
# 4                  2.857143                            1109.857143
#
# [5 rows x 67 columns]

# %%
imputed_df[imputed_df.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [ar_daily_mostcommonactivity, ar_daily_sumstationary, ar_daily_sumvehicle, ar_daily_summobile, ar_daily_activitychangecount, ar_daily_count, ar_daily_countuniqueactivities, call_incoming_daily_count, call_incoming_daily_distinctcontacts, call_incoming_daily_meanduration, call_incoming_daily_sumduration, call_incoming_daily_minduration, call_incoming_daily_maxduration, call_incoming_daily_modeduration, call_incoming_daily_timefirstcall, call_incoming_daily_timelastcall, call_missed_daily_count, call_missed_daily_distinctcontacts, call_missed_daily_timefirstcall, call_missed_daily_timelastcall, call_outgoing_daily_count, call_outgoing_daily_distinctcontacts, call_outgoing_daily_meanduration, call_outgoing_daily_sumduration, call_outgoing_daily_maxduration, call_outgoing_daily_modeduration, call_outgoing_daily_timefirstcall, call_outgoing_daily_timelastcall, conversation_daily_minutesnoise, conversation_daily_noisesensedfraction, conversation_daily_noiseexpectedfraction, conversation_daily_noisesumenergy, conversation_daily_noiseavgenergy, conversation_daily_noisesdenergy, conversation_daily_noiseminenergy, conversation_daily_noisemaxenergy, location_daily_locationvariance, location_daily_loglocationvariance, location_daily_totaldistance, location_daily_averagespeed, location_daily_varspeed, location_daily_circadianmovement, location_daily_numberofsignificantplaces, location_daily_numberlocationtransitions, location_daily_radiusgyration, location_daily_timeattop1location, location_daily_timeattop2location, location_daily_timeattop3location, location_daily_movingtostaticratio, location_daily_outlierstimepercent, location_daily_maxlengthstayatclusters, location_daily_minlengthstayatclusters, location_daily_stdlengthstayatclusters, location_daily_meanlengthstayatclusters, location_daily_locationentropy, location_daily_normalizedlocationentropy, screen_daily_countepisodeunlock, screen_daily_avgdurationunlock, screen_daily_episodepersensedminutesunlock, screen_daily_firstuseafter00unlock, screen_daily_stddurationunlock, screen_daily_maxdurationunlock, screen_daily_sumdurationunlock, screen_daily_mindurationunlock, wifi_daily_countscans, wifi_daily_uniquedevices, wifi_daily_countscansmostuniquedevice]
# Index: []
#
# [0 rows x 67 columns]

# %%
from pandas import set_option 
from pandas.plotting import scatter_matrix 
from sklearn.preprocessing import StandardScaler 
from sklearn.model_selection import train_test_split 
from sklearn.model_selection import KFold 
from sklearn.model_selection import cross_val_score 
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import Pipeline 

from sklearn.linear_model import LinearRegression 
from sklearn.linear_model import Lasso 
from sklearn.linear_model import ElasticNet 
from sklearn.tree import DecisionTreeRegressor 
from sklearn.neighbors import KNeighborsRegressor 
from sklearn.svm import SVR 
from sklearn.ensemble import RandomForestRegressor 
from sklearn.ensemble import GradientBoostingRegressor 
from sklearn.ensemble import ExtraTreesRegressor 
from sklearn.ensemble import AdaBoostRegressor
from sklearn.metrics import mean_squared_error

# %%
imputed_df.info();
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 462 entries, 0 to 461
# Data columns (total 67 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   ar_daily_mostcommonactivity                 462 non-null    float64
#  1   ar_daily_sumstationary                      462 non-null    float64
#  2   ar_daily_sumvehicle                         462 non-null    float64
#  3   ar_daily_summobile                          462 non-null    float64
#  4   ar_daily_activitychangecount                462 non-null    float64
#  5   ar_daily_count                              462 non-null    float64
#  6   ar_daily_countuniqueactivities              462 non-null    float64
#  7   call_incoming_daily_count                   462 non-null    float64
#  8   call_incoming_daily_distinctcontacts        462 non-null    float64
#  9   call_incoming_daily_meanduration            462 non-null    float64
#  10  call_incoming_daily_sumduration             462 non-null    float64
#  11  call_incoming_daily_minduration             462 non-null    float64
#  12  call_incoming_daily_maxduration             462 non-null    float64
#  13  call_incoming_daily_modeduration            462 non-null    float64
#  14  call_incoming_daily_timefirstcall           462 non-null    float64
#  15  call_incoming_daily_timelastcall            462 non-null    float64
#  16  call_missed_daily_count                     462 non-null    float64
#  17  call_missed_daily_distinctcontacts          462 non-null    float64
#  18  call_missed_daily_timefirstcall             462 non-null    float64
#  19  call_missed_daily_timelastcall              462 non-null    float64
#  20  call_outgoing_daily_count                   462 non-null    float64
#  21  call_outgoing_daily_distinctcontacts        462 non-null    float64
#  22  call_outgoing_daily_meanduration            462 non-null    float64
#  23  call_outgoing_daily_sumduration             462 non-null    float64
#  24  call_outgoing_daily_maxduration             462 non-null    float64
#  25  call_outgoing_daily_modeduration            462 non-null    float64
#  26  call_outgoing_daily_timefirstcall           462 non-null    float64
#  27  call_outgoing_daily_timelastcall            462 non-null    float64
#  28  conversation_daily_minutesnoise             462 non-null    float64
#  29  conversation_daily_noisesensedfraction      462 non-null    float64
#  30  conversation_daily_noiseexpectedfraction    462 non-null    float64
#  31  conversation_daily_noisesumenergy           462 non-null    float64
#  32  conversation_daily_noiseavgenergy           462 non-null    float64
#  33  conversation_daily_noisesdenergy            462 non-null    float64
#  34  conversation_daily_noiseminenergy           462 non-null    float64
#  35  conversation_daily_noisemaxenergy           462 non-null    float64
#  36  location_daily_locationvariance             462 non-null    float64
#  37  location_daily_loglocationvariance          462 non-null    float64
#  38  location_daily_totaldistance                462 non-null    float64
#  39  location_daily_averagespeed                 462 non-null    float64
#  40  location_daily_varspeed                     462 non-null    float64
#  41  location_daily_circadianmovement            462 non-null    float64
#  42  location_daily_numberofsignificantplaces    462 non-null    float64
#  43  location_daily_numberlocationtransitions    462 non-null    float64
#  44  location_daily_radiusgyration               462 non-null    float64
#  45  location_daily_timeattop1location           462 non-null    float64
#  46  location_daily_timeattop2location           462 non-null    float64
#  47  location_daily_timeattop3location           462 non-null    float64
#  48  location_daily_movingtostaticratio          462 non-null    float64
#  49  location_daily_outlierstimepercent          462 non-null    float64
#  50  location_daily_maxlengthstayatclusters      462 non-null    float64
#  51  location_daily_minlengthstayatclusters      462 non-null    float64
#  52  location_daily_stdlengthstayatclusters      462 non-null    float64
#  53  location_daily_meanlengthstayatclusters     462 non-null    float64
#  54  location_daily_locationentropy              462 non-null    float64
#  55  location_daily_normalizedlocationentropy    462 non-null    float64
#  56  screen_daily_countepisodeunlock             462 non-null    float64
#  57  screen_daily_avgdurationunlock              462 non-null    float64
#  58  screen_daily_episodepersensedminutesunlock  462 non-null    float64
#  59  screen_daily_firstuseafter00unlock          462 non-null    float64
#  60  screen_daily_stddurationunlock              462 non-null    float64
#  61  screen_daily_maxdurationunlock              462 non-null    float64
#  62  screen_daily_sumdurationunlock              462 non-null    float64
#  63  screen_daily_mindurationunlock              462 non-null    float64
#  64  wifi_daily_countscans                       462 non-null    float64
#  65  wifi_daily_uniquedevices                    462 non-null    float64
#  66  wifi_daily_countscansmostuniquedevice       462 non-null    float64
# dtypes: float64(67)
# memory usage: 242.0 KB

# %%
imputed_df.corr()

# %%
# Test options and evaluation metric 
num_folds = 10 
seed = 7
scoring = ' neg_mean_squared_error'

# %%
# Out:
#                                        ar_daily_mostcommonactivity  \
# ar_daily_mostcommonactivity                               1.000000
# ar_daily_sumstationary                                    0.353754
# ar_daily_sumvehicle                                      -0.194288
# ar_daily_summobile                                        0.358689
# ar_daily_activitychangecount                              0.627336
# ...                                                            ...
# screen_daily_sumdurationunlock                            0.097721
# screen_daily_mindurationunlock                            0.025267
# wifi_daily_countscans                                     0.132697
# wifi_daily_uniquedevices                                 -0.097125
# wifi_daily_countscansmostuniquedevice                     0.201007
#
#                                        ar_daily_sumstationary  \
# ar_daily_mostcommonactivity                          0.353754
# ar_daily_sumstationary                               1.000000
# ar_daily_sumvehicle                                  0.464088
# ar_daily_summobile                                   0.480165
# ar_daily_activitychangecount                         0.645186
# ...                                                       ...
# screen_daily_sumdurationunlock                       0.083788
# screen_daily_mindurationunlock                      -0.054626
# wifi_daily_countscans                                0.293795
# wifi_daily_uniquedevices                             0.049480
# wifi_daily_countscansmostuniquedevice                0.183380
#
#                                        ar_daily_sumvehicle  \
# ar_daily_mostcommonactivity                      -0.194288
# ar_daily_sumstationary                            0.464088
# ar_daily_sumvehicle                               1.000000
# ar_daily_summobile                                0.288923
# ar_daily_activitychangecount                      0.049131
# ...                                                    ...
# screen_daily_sumdurationunlock                    0.078100
# screen_daily_mindurationunlock                   -0.080269
# wifi_daily_countscans                             0.191310
# wifi_daily_uniquedevices                          0.086317
# wifi_daily_countscansmostuniquedevice            -0.019784
#
#                                        ar_daily_summobile  \
# ar_daily_mostcommonactivity                      0.358689
# ar_daily_sumstationary                           0.480165
# ar_daily_sumvehicle                              0.288923
# ar_daily_summobile                               1.000000
# ar_daily_activitychangecount                     0.328581
# ...                                                   ...
# screen_daily_sumdurationunlock                   0.182256
# screen_daily_mindurationunlock                  -0.169883
# wifi_daily_countscans                            0.083497
# wifi_daily_uniquedevices                         0.038016
# wifi_daily_countscansmostuniquedevice            0.049266
#
#                                        ar_daily_activitychangecount  \
# ar_daily_mostcommonactivity                                0.627336
# ar_daily_sumstationary                                     0.645186
# ar_daily_sumvehicle                                        0.049131
# ar_daily_summobile                                         0.328581
# ar_daily_activitychangecount                               1.000000
# ...                                                             ...
# screen_daily_sumdurationunlock                             0.057589
# screen_daily_mindurationunlock                             0.012810
# wifi_daily_countscans                                      0.292867
# wifi_daily_uniquedevices                                   0.025941
# wifi_daily_countscansmostuniquedevice                      0.263669
#
#                                        ar_daily_count  \
# ar_daily_mostcommonactivity                  0.211386
# ar_daily_sumstationary                      -0.065327
# ar_daily_sumvehicle                         -0.061753
# ar_daily_summobile                           0.183963
# ar_daily_activitychangecount                -0.211587
# ...                                               ...
# screen_daily_sumdurationunlock               0.127384
# screen_daily_mindurationunlock               0.196208
# wifi_daily_countscans                       -0.297899
# wifi_daily_uniquedevices                    -0.074485
# wifi_daily_countscansmostuniquedevice       -0.188760
#
#                                        ar_daily_countuniqueactivities  \
# ar_daily_mostcommonactivity                                  0.182435
# ar_daily_sumstationary                                      -0.112227
# ar_daily_sumvehicle                                          0.110530
# ar_daily_summobile                                          -0.043237
# ar_daily_activitychangecount                                -0.011367
# ...                                                               ...
# screen_daily_sumdurationunlock                              -0.018784
# screen_daily_mindurationunlock                               0.113983
# wifi_daily_countscans                                       -0.072784
# wifi_daily_uniquedevices                                    -0.076851
# wifi_daily_countscansmostuniquedevice                       -0.056644
#
#                                        call_incoming_daily_count  \
# ar_daily_mostcommonactivity                             0.281326
# ar_daily_sumstationary                                  0.022148
# ar_daily_sumvehicle                                    -0.075844
# ar_daily_summobile                                      0.010620
# ar_daily_activitychangecount                            0.087084
# ...                                                          ...
# screen_daily_sumdurationunlock                         -0.006936
# screen_daily_mindurationunlock                         -0.037799
# wifi_daily_countscans                                   0.174833
# wifi_daily_uniquedevices                                0.073885
# wifi_daily_countscansmostuniquedevice                   0.101063
#
#                                        call_incoming_daily_distinctcontacts  \
# ar_daily_mostcommonactivity                                        0.308286
# ar_daily_sumstationary                                             0.031445
# ar_daily_sumvehicle                                               -0.090073
# ar_daily_summobile                                                 0.023260
# ar_daily_activitychangecount                                       0.111768
# ...                                                                     ...
# screen_daily_sumdurationunlock                                    -0.001345
# screen_daily_mindurationunlock                                    -0.037965
# wifi_daily_countscans                                              0.175330
# wifi_daily_uniquedevices                                           0.039859
# wifi_daily_countscansmostuniquedevice                              0.122998
#
#                                        call_incoming_daily_meanduration  ...  \
# ar_daily_mostcommonactivity                                    0.042150  ...
# ar_daily_sumstationary                                         0.065058  ...
# ar_daily_sumvehicle                                           -0.011093  ...
# ar_daily_summobile                                            -0.005283  ...
# ar_daily_activitychangecount                                   0.116073  ...
# ...                                                                 ...  ...
# screen_daily_sumdurationunlock                                 0.029512  ...
# screen_daily_mindurationunlock                                -0.153204  ...
# wifi_daily_countscans                                          0.088776  ...
# wifi_daily_uniquedevices                                      -0.011775  ...
# wifi_daily_countscansmostuniquedevice                          0.089929  ...
#
#                                        screen_daily_avgdurationunlock  \
# ar_daily_mostcommonactivity                                  0.399980
# ar_daily_sumstationary                                       0.229913
# ar_daily_sumvehicle                                         -0.001143
# ar_daily_summobile                                           0.168106
# ar_daily_activitychangecount                                 0.274875
# ...                                                               ...
# screen_daily_sumdurationunlock                               0.077924
# screen_daily_mindurationunlock                              -0.102567
# wifi_daily_countscans                                        0.499259
# wifi_daily_uniquedevices                                     0.144238
# wifi_daily_countscansmostuniquedevice                        0.214649
#
#                                        screen_daily_episodepersensedminutesunlock  \
# ar_daily_mostcommonactivity                                              0.219426
# ar_daily_sumstationary                                                   0.281434
# ar_daily_sumvehicle                                                      0.200821
# ar_daily_summobile                                                       0.353471
# ar_daily_activitychangecount                                             0.255500
# ...                                                                           ...
# screen_daily_sumdurationunlock                                           0.504801
# screen_daily_mindurationunlock                                          -0.359385
# wifi_daily_countscans                                                    0.502053
# wifi_daily_uniquedevices                                                 0.047839
# wifi_daily_countscansmostuniquedevice                                    0.307155
#
#                                        screen_daily_firstuseafter00unlock  \
# ar_daily_mostcommonactivity                                      0.115753
# ar_daily_sumstationary                                           0.091766
# ar_daily_sumvehicle                                              0.099258
# ar_daily_summobile                                               0.197387
# ar_daily_activitychangecount                                     0.041712
# ...                                                                   ...
# screen_daily_sumdurationunlock                                   0.887197
# screen_daily_mindurationunlock                                  -0.106729
# wifi_daily_countscans                                           -0.049956
# wifi_daily_uniquedevices                                        -0.028668
# wifi_daily_countscansmostuniquedevice                           -0.022534
#
#                                        screen_daily_stddurationunlock  \
# ar_daily_mostcommonactivity                                 -0.115875
# ar_daily_sumstationary                                      -0.067575
# ar_daily_sumvehicle                                         -0.043767
# ar_daily_summobile                                          -0.082092
# ar_daily_activitychangecount                                -0.037775
# ...                                                               ...
# screen_daily_sumdurationunlock                               0.195459
# screen_daily_mindurationunlock                               0.079534
# wifi_daily_countscans                                       -0.070350
# wifi_daily_uniquedevices                                    -0.013286
# wifi_daily_countscansmostuniquedevice                       -0.068540
#
#                                        screen_daily_maxdurationunlock  \
# ar_daily_mostcommonactivity                                 -0.032892
# ar_daily_sumstationary                                       0.011264
# ar_daily_sumvehicle                                          0.029579
# ar_daily_summobile                                           0.051852
# ar_daily_activitychangecount                                 0.026704
# ...                                                               ...
# screen_daily_sumdurationunlock                               0.657022
# screen_daily_mindurationunlock                               0.017945
# wifi_daily_countscans                                       -0.091637
# wifi_daily_uniquedevices                                    -0.039268
# wifi_daily_countscansmostuniquedevice                       -0.036520
#
#                                        screen_daily_sumdurationunlock  \
# ar_daily_mostcommonactivity                                  0.097721
# ar_daily_sumstationary                                       0.083788
# ar_daily_sumvehicle                                          0.078100
# ar_daily_summobile                                           0.182256
# ar_daily_activitychangecount                                 0.057589
# ...                                                               ...
# screen_daily_sumdurationunlock                               1.000000
# screen_daily_mindurationunlock                              -0.050778
# wifi_daily_countscans                                       -0.136309
# wifi_daily_uniquedevices                                    -0.050451
# wifi_daily_countscansmostuniquedevice                       -0.047304
#
#                                        screen_daily_mindurationunlock  \
# ar_daily_mostcommonactivity                                  0.025267
# ar_daily_sumstationary                                      -0.054626
# ar_daily_sumvehicle                                         -0.080269
# ar_daily_summobile                                          -0.169883
# ar_daily_activitychangecount                                 0.012810
# ...                                                               ...
# screen_daily_sumdurationunlock                              -0.050778
# screen_daily_mindurationunlock                               1.000000
# wifi_daily_countscans                                       -0.117802
# wifi_daily_uniquedevices                                    -0.029350
# wifi_daily_countscansmostuniquedevice                        0.021326
#
#                                        wifi_daily_countscans  \
# ar_daily_mostcommonactivity                         0.132697
# ar_daily_sumstationary                              0.293795
# ar_daily_sumvehicle                                 0.191310
# ar_daily_summobile                                  0.083497
# ar_daily_activitychangecount                        0.292867
# ...                                                      ...
# screen_daily_sumdurationunlock                     -0.136309
# screen_daily_mindurationunlock                     -0.117802
# wifi_daily_countscans                               1.000000
# wifi_daily_uniquedevices                            0.291070
# wifi_daily_countscansmostuniquedevice               0.587152
#
#                                        wifi_daily_uniquedevices  \
# ar_daily_mostcommonactivity                           -0.097125
# ar_daily_sumstationary                                 0.049480
# ar_daily_sumvehicle                                    0.086317
# ar_daily_summobile                                     0.038016
# ar_daily_activitychangecount                           0.025941
# ...                                                         ...
# screen_daily_sumdurationunlock                        -0.050451
# screen_daily_mindurationunlock                        -0.029350
# wifi_daily_countscans                                  0.291070
# wifi_daily_uniquedevices                               1.000000
# wifi_daily_countscansmostuniquedevice                 -0.033622
#
#                                        wifi_daily_countscansmostuniquedevice
# ar_daily_mostcommonactivity                                         0.201007
# ar_daily_sumstationary                                              0.183380
# ar_daily_sumvehicle                                                -0.019784
# ar_daily_summobile                                                  0.049266
# ar_daily_activitychangecount                                        0.263669
# ...                                                                      ...
# screen_daily_sumdurationunlock                                     -0.047304
# screen_daily_mindurationunlock                                      0.021326
# wifi_daily_countscans                                               0.587152
# wifi_daily_uniquedevices                                           -0.033622
# wifi_daily_countscansmostuniquedevice                               1.000000
#
# [67 rows x 67 columns]

# %%
# Test options and evaluation metric 
num_folds = 10 
seed = 7
scoring = ' neg_mean_squared_error'
