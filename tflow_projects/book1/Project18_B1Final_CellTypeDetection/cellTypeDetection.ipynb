# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from tensorflow.keras.preprocessing.image import img_to_array
from loader_util.preprocessing import AspectAwarePreprocessor, ImageToArrayPreprocessor
from loader_util.datasets import SimpleDatasetLoader
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.optimizers import SGD
from loader_util.nn.conv import LeNet
from imutils import paths
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.axes._axes as axes
import cv2
import os
sns.set()

# %%
dataFolder = r"C:\Users\mhasa\Google Drive\Tutorial " \
             r"Corner\PYTH\DeepLearning\DeepLearning-DL4CV\ImageDatasets\cellImages2"

args = {
    'dataset': dataFolder
}

imagePaths = list(paths.list_images(args['dataset']))

# %%
# initialise the preprocessors
sp = AspectAwarePreprocessor(224, 224)
iap = ImageToArrayPreprocessor()

# load the dataset
sdl = SimpleDatasetLoader(preprocessors=[sp, iap])
data, labels = sdl.load(imagePaths, verbose=100)
data = data.astype('float') / 255.0
# Out:
# [INFO] processed 100/1337
# [INFO] processed 200/1337
# [INFO] processed 300/1337
# [INFO] processed 400/1337
# [INFO] processed 500/1337
# [INFO] processed 600/1337
# [INFO] processed 700/1337
# [INFO] processed 800/1337
# [INFO] processed 900/1337
# [INFO] processed 1000/1337
# [INFO] processed 1100/1337
# [INFO] processed 1200/1337
# [INFO] processed 1300/1337

# %%
# data_gray = []
# 
# for ind, processed_image in enumerate(data):
#     gray = cv2.cvtColor(processed_image, cv2.COLOR_BGR2GRAY)
#     gray = img_to_array(gray)
#     #print(processed_image.shape)
#     #print(gray.shape)
#     data_gray.append(gray)
# data_gray = np.array(data_gray)
# data = data_gray.astype('float') / 255.0 # scale image to 0-1

# %%
le = LabelEncoder().fit(labels)
labels = to_categorical(le.transform(labels), 3)
trainx, testx, trainy, testy = train_test_split(data, labels, test_size=0.2,
                                                random_state=42, stratify=labels)

# imbalance
classTotals = labels.sum(axis=0)
classWeight = classTotals.max() / classTotals

# %%
epoch_no = 20
opt = SGD(learning_rate=0.005)
model = LeNet.build(width=224, height=224, depth=3, classes=3)
model.compile(loss='categorical_crossentropy', optimizer=opt, 
              metrics=['accuracy'])
H = model.fit(trainx,
              trainy, validation_data=[testx, testy],
              batch_size=10,
              epochs=epoch_no,
              verbose=1,
              class_weight=classWeight)
# Out:
# Train on 1069 samples, validate on 268 samples
# Epoch 1/20
# 1069/1069 [==============================] - 13s 12ms/sample - loss: 1.0984 - accuracy: 0.3770 - val_loss: 1.0854 - val_accuracy: 0.3619
# Epoch 2/20
#  - ETA: 2s - loss: 1.0858 - accuracy: 0.3897
# Epoch 3/20
# 1069/1069 [==============================] - 11s 10ms/sample - loss: 1.0826 - accuracy: 0.4088 - val_loss: 1.0694 - val_accuracy: 0.5634
# Epoch 4/20
#  - ETA: 3s - loss: 1.0740 - accuracy: 0.4016
# Epoch 5/20
#  - ETA: 6s - loss: 1.0729 - accuracy: 0.4465
# Epoch 6/20
# 1069/1069 [==============================] - 11s 11ms/sample - loss: 1.0739 - accuracy: 0.4022 - val_loss: 1.0517 - val_accuracy: 0.5224
# Epoch 7/20
#  - ETA: 8s - loss: 1.0665 - accuracy: 0.4708
# Epoch 8/20
# 1069/1069 [==============================] - 11s 10ms/sample - loss: 1.0537 - accuracy: 0.4593 - val_loss: 1.0298 - val_accuracy: 0.3694
# Epoch 9/20
# 1069/1069 [==============================] - 11s 11ms/sample - loss: 1.0471 - accuracy: 0.4659 - val_loss: 1.0131 - val_accuracy: 0.5373
# Epoch 10/20
# 1069/1069 [==============================] - 12s 11ms/sample - loss: 1.0191 - accuracy: 0.4846 - val_loss: 1.0832 - val_accuracy: 0.3470
# Epoch 11/20
#  - ETA: 5s - loss: 1.0418 - accuracy: 0.4706
# Epoch 12/20
# 1069/1069 [==============================] - 11s 10ms/sample - loss: 0.9840 - accuracy: 0.5220 - val_loss: 0.9648 - val_accuracy: 0.5709
# Epoch 13/20
#  - ETA: 3s - loss: 0.9841 - accuracy: 0.5243
# Epoch 14/20
# 1069/1069 [==============================] - 11s 10ms/sample - loss: 0.9337 - accuracy: 0.5267 - val_loss: 0.9387 - val_accuracy: 0.5560
# Epoch 15/20
#  - ETA: 4s - loss: 0.9297 - accuracy: 0.5565
# Epoch 16/20
#  - ETA: 0s - loss: 0.8664 - accuracy: 0.5910
# Epoch 17/20
#  - ETA: 6s - loss: 0.8718 - accuracy: 0.6024
# Epoch 18/20
#  - ETA: 6s - loss: 0.7641 - accuracy: 0.6722
# Epoch 19/20
#  - ETA: 1s - loss: 0.7445 - accuracy: 0.6489
# Epoch 20/20
#  - ETA: 5s - loss: 0.6872 - accuracy: 0.7196

# %%
# evaluate the network
preds = model.predict(testx, batch_size=10)
rep = classification_report(testy.argmax(axis=1), preds.argmax(axis=1), 
                            target_names=le.classes_)
print(rep)
# Out:
#               precision    recall  f1-score   support
#
#          3T3       0.62      0.49      0.55        97
#         MG63       0.41      0.60      0.48        92
#         hASC       0.86      0.61      0.71        79
#
#     accuracy                           0.56       268
#    macro avg       0.63      0.57      0.58       268
# weighted avg       0.62      0.56      0.58       268

# %%
epochs = range(1,epoch_no+1)
loss = H.history['loss']
accuracy = H.history['accuracy']
val_loss = H.history['val_loss']
val_accuracy = H.history['val_accuracy']
plot_df = pd.DataFrame(data=np.c_[epochs,loss,accuracy,val_loss,val_accuracy], 
                       columns=['epochs','loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
sns.set(font_scale=1)
f, ax = plt.subplots(1, 1, figsize=(15,8))
sns.lineplot(data=plot_df, x='epochs', y='loss', ax=ax, label='train loss', linewidth=3)
sns.lineplot(data=plot_df, x='epochs', y='accuracy', ax=ax, label='train accuracy', linewidth=3)
sns.lineplot(data=plot_df, x='epochs', y='val_loss', ax=ax, label='val loss', linewidth=3)
sns.lineplot(data=plot_df, x='epochs', y='val_accuracy', ax=ax, label='val_accuracy', linewidth=3)
ax.set_ylabel('Loss or Accuracy')
ax.set_xlabel('Epochs')
plt.setp(ax.get_legend().get_texts(), fontsize='18'); # for legend text

# %%
model.save('./checkpoint')
# Out:
# WARNING:tensorflow:From c:\users\mhasa\google drive\tutorial corner\pyth\pycharm projects\deeplearningcv\venv\lib\site-packages\tensorflow_core\python\ops\resource_variable_ops.py:1781: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# INFO:tensorflow:Assets written to: ./checkpoint\assets
