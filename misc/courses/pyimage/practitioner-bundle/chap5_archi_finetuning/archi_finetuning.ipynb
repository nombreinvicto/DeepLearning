# %%
import sys
from google.colab import drive

drive.mount('/content/drive')
sys.path.append(r"/content/drive/MyDrive/")
# Out:
# Mounted at /content/drive

# %%
! pip install opencv-python
! pip install colab-xterm
# %load_ext colabxterm
# %xterm
# Out:
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.12/dist-packages (4.12.0.88)
# Requirement already satisfied: numpy<2.3.0,>=2 in /usr/local/lib/python3.12/dist-packages (from opencv-python) (2.0.2)
# Collecting colab-xterm
#   Downloading colab_xterm-0.2.0-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: ptyprocess~=0.7.0 in /usr/local/lib/python3.12/dist-packages (from colab-xterm) (0.7.0)
# Requirement already satisfied: tornado>5.1 in /usr/local/lib/python3.12/dist-packages (from colab-xterm) (6.4.2)
# Downloading colab_xterm-0.2.0-py3-none-any.whl (115 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.6/115.6 kB 11.8 MB/s eta 0:00:00
# Installing collected packages: colab-xterm
# Successfully installed colab-xterm-0.2.0
# Launching Xterm...

# %%
import sys, os, json
import numpy as np
import pandas as pd
import seaborn as sns
import argparse, progressbar
import matplotlib.pyplot as plt
from matplotlib.figure import Figure
from matplotlib.axes import Axes

sns.set()

# %%
# import the necessary packages
from imutils import paths
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from loader_util.preprocessing import (ImageToArrayPreprocessor,
                                       AspectAwarePreprocessor,
                                       SimplePreprocessor,
                                       MeanPreprocessor)
from loader_util.io import HDF5DatasetGenerator
from loader_util.datasets import SimpleDatasetLoader
from loader_util.nn.conv import FCHeadNet

##
import tensorflow as tf
from tensorflow.keras import backend as K
from tensorflow.keras import layers
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import RMSprop, SGD
from tensorflow.keras.regularizers import l2
from tensorflow.keras.applications import VGG16
from tensorflow.keras.models import Model, load_model

# %%
# script constants
args = {
    "dataset_path": r"/content/drive/MyDrive/Colab Notebooks/ImageDataset/book2/flowers17/images",
}

# %%
# augmentor
aug = ImageDataGenerator(rotation_range=30,
                         width_shift_range=0.1,
                         height_shift_range=0.1,
                         shear_range=0.2,
                         zoom_range=0.2,
                         horizontal_flip=True,
                         fill_mode='nearest',
                         )

# %%
print(f"[INFO] loading images......")
image_paths = list(paths.list_images(args["dataset_path"]))
class_names = [pth.split(os.path.sep)[-2] for pth in image_paths]
class_names = np.unique(class_names)
print(class_names)
# Out:
# [INFO] loading images......
# ['bluebell' 'buttercup' 'coltsfoot' 'cowslip' 'crocus' 'daffodil' 'daisy'
#  'dandelion' 'fritillary' 'iris' 'lilyvalley' 'pansy' 'snowdrop'
#  'sunflower' 'tigerlily' 'tulip' 'windflower']

# %%
# init the preprocessors
aap = AspectAwarePreprocessor(224, 224)
iap = ImageToArrayPreprocessor()

# load the dataset from disk
# simple dataset loader uses opencv - BGR
sdl = SimpleDatasetLoader(preprocessors=[aap, iap])
data, labels = sdl.load(image_paths, verbose=500)
data = data.astype("float") / 255.0
# Out:
# [INFO] processed 500/1360
# [INFO] processed 1000/1360

# %%
trainx, testx, trainy, testy = train_test_split(data,
                                                labels,
                                                test_size=0.25,
                                                random_state=42)

lb = LabelBinarizer()
trainy_encoded = lb.fit_transform(trainy)
testy_encoded = lb.transform(testy)

# %%
# load vgg16 without the head
base_model = VGG16(include_top=False,
                   weights="imagenet",
                   input_tensor=layers.Input(shape=(224, 224, 3)))

head_model = FCHeadNet.build(base_model=base_model,
                             output_classes=len(class_names),
                             dense_layer_nodes=[256])

model = Model(inputs=base_model.input,
              outputs=head_model)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 4s 0us/step

# %%
for layer in base_model.layers:
    layer.trainable = False

# %%
print(f"[INFO] compiling the model......")
opt = RMSprop(learning_rate=0.001)
model.compile(optimizer=opt,
              loss="categorical_crossentropy",
              metrics=["accuracy"])
# Out:
# [INFO] compiling the model......

# %%
print(f"[INFO] training the head......")
H1 = model.fit(aug.flow(trainx, trainy_encoded, batch_size=32),
          validation_data=(testx, testy_encoded),
          epochs=25,
          steps_per_epoch=len(trainx)//32,
          verbose=1)
# Out:
# [INFO] training the head......
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/25
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 46s 1s/step - accuracy: 0.1342 - loss: 7.9347 - val_accuracy: 0.2853 - val_loss: 2.2068
# Epoch 2/25
#  1/31 ━━━━━━━━━━━━━━━━━━━━ 4s 143ms/step - accuracy: 0.2188 - loss: 2.4828
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/epoch_iterator.py:116: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - accuracy: 0.2188 - loss: 2.4828 - val_accuracy: 0.4176 - val_loss: 2.1357
# Epoch 3/25
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 11s 351ms/step - accuracy: 0.2345 - loss: 2.4353 - val_accuracy: 0.3794 - val_loss: 1.8671
# Epoch 4/25
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - accuracy: 0.2812 - loss: 2.4497 - val_accuracy: 0.4471 - val_loss: 1.8184
# Epoch 5/25
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 11s 367ms/step - accuracy: 0.3296 - loss: 2.0693 - val_accuracy: 0.6088 - val_loss: 1.4490
# Epoch 6/25
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - accuracy: 0.3125 - loss: 1.9597 - val_accuracy: 0.6265 - val_loss: 1.3727
# Epoch 7/25
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 11s 360ms/step - accuracy: 0.3682 - loss: 1.9419 - val_accuracy: 0.6353 - val_loss: 1.2367
# Epoch 8/25
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - accuracy: 0.4375 - loss: 1.6731 - val_accuracy: 0.6912 - val_loss: 1.1173
# Epoch 9/25
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 11s 354ms/step - accuracy: 0.4674 - loss: 1.6438 - val_accuracy: 0.7235 - val_loss: 1.0505
# Epoch 10/25
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - accuracy: 0.5000 - loss: 1.3033 - val_accuracy: 0.7088 - val_loss: 1.0103
# Epoch 11/25
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 11s 364ms/step - accuracy: 0.4768 - loss: 1.5512 - val_accuracy: 0.7559 - val_loss: 0.8948
# Epoch 12/25
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - accuracy: 0.4375 - loss: 1.4723 - val_accuracy: 0.8000 - val_loss: 0.8765
# Epoch 13/25
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 11s 368ms/step - accuracy: 0.5587 - loss: 1.3727 - val_accuracy: 0.7765 - val_loss: 0.7772
# Epoch 14/25
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - accuracy: 0.5000 - loss: 1.4324 - val_accuracy: 0.7676 - val_loss: 0.8361
# Epoch 15/25
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 12s 372ms/step - accuracy: 0.5327 - loss: 1.3999 - val_accuracy: 0.7824 - val_loss: 0.7339
# Epoch 16/25
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - accuracy: 0.6071 - loss: 1.3168 - val_accuracy: 0.8294 - val_loss: 0.6794
# Epoch 17/25
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 11s 359ms/step - accuracy: 0.5721 - loss: 1.2531 - val_accuracy: 0.7412 - val_loss: 0.7706
# Epoch 18/25
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - accuracy: 0.7188 - loss: 0.9848 - val_accuracy: 0.8353 - val_loss: 0.6431
# Epoch 19/25
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 11s 357ms/step - accuracy: 0.5973 - loss: 1.2437 - val_accuracy: 0.8265 - val_loss: 0.6538
# Epoch 20/25
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - accuracy: 0.6250 - loss: 1.1354 - val_accuracy: 0.8471 - val_loss: 0.6048
# Epoch 21/25
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 11s 355ms/step - accuracy: 0.6296 - loss: 1.1254 - val_accuracy: 0.8324 - val_loss: 0.6488
# Epoch 22/25
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - accuracy: 0.5625 - loss: 1.2937 - val_accuracy: 0.8118 - val_loss: 0.6431
# Epoch 23/25
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 11s 357ms/step - accuracy: 0.6687 - loss: 0.9981 - val_accuracy: 0.7853 - val_loss: 0.6599
# Epoch 24/25
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - accuracy: 0.6250 - loss: 1.1316 - val_accuracy: 0.8088 - val_loss: 0.6500
# Epoch 25/25
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 11s 348ms/step - accuracy: 0.6752 - loss: 1.0200 - val_accuracy: 0.8441 - val_loss: 0.5055

# %%
# evaluate the network
# evaluate the network
print("[INFO] evaluating network...")
predictions = model.predict(testx, batch_size=32)
print(classification_report(testy_encoded.argmax(axis=1),
                            predictions.argmax(axis=1), target_names=class_names))

# plot the performance
epochs = range(1, 26)
loss = H1.history['loss']
accuracy = H1.history['accuracy']
val_loss = H1.history['val_loss']
val_accuracy = H1.history['val_accuracy']
plot_df = pd.DataFrame(data=np.c_[epochs, loss, accuracy, val_loss, val_accuracy],
                       columns=['epochs', 'loss', 'accuracy', 'val_loss', 'val_accuracy'])

# do the actual plots
sns.set(font_scale=1)
f, ax = plt.subplots(1, 1, figsize=(10, 6))
sns.lineplot(data=plot_df, x='epochs', y='loss', ax=ax, label='train loss', linewidth=3)
sns.lineplot(data=plot_df, x='epochs', y='accuracy', ax=ax, label='train accuracy', linewidth=3)
sns.lineplot(data=plot_df, x='epochs', y='val_loss', ax=ax, label='val loss', linewidth=3)
sns.lineplot(data=plot_df, x='epochs', y='val_accuracy', ax=ax, label='val_accuracy', linewidth=3)
ax.set_ylabel('Loss or Accuracy')
ax.set_xlabel('Epochs');
# Out:
# [INFO] evaluating network...
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 154ms/step
#               precision    recall  f1-score   support
#
#     bluebell       0.70      0.80      0.74        20
#    buttercup       0.83      0.95      0.88        20
#    coltsfoot       0.71      0.94      0.81        16
#      cowslip       0.86      0.63      0.73        19
#       crocus       1.00      0.60      0.75        15
#     daffodil       0.82      0.90      0.86        20
#        daisy       0.91      0.91      0.91        23
#    dandelion       1.00      0.74      0.85        27
#   fritillary       0.79      1.00      0.88        19
#         iris       0.95      0.90      0.93        21
#   lilyvalley       0.80      0.89      0.84        18
#        pansy       0.94      0.94      0.94        16
#     snowdrop       0.80      0.73      0.76        22
#    sunflower       1.00      0.96      0.98        23
#    tigerlily       0.77      0.94      0.85        18
#        tulip       1.00      0.55      0.71        20
#   windflower       0.73      0.96      0.83        23
#
#     accuracy                           0.84       340
#    macro avg       0.86      0.84      0.84       340
# weighted avg       0.86      0.84      0.84       340

# %%
# after warming up FC layers, lets unfreeze final set of conv layers
for layer in base_model.layers[15:]:
    layer.trainable = True

# %%
print(f"[INFO] recompiling the model......")
opt = SGD(learning_rate=0.001)
model.compile(optimizer=opt,
              loss="categorical_crossentropy",
              metrics=["accuracy"])
print(f"[INFO] fine tuning the model......")
H2 = model.fit(aug.flow(trainx, trainy_encoded, batch_size=32),
               validation_data=(testx, testy_encoded),
               epochs=100,
               steps_per_epoch=len(trainx)//32,
               verbose=1)
# Out:
# [INFO] recompiling the model......
# [INFO] fine tuning the model......
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━
# Epoch 90/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - accuracy: 0.6562 - loss: 0.8732 - val_accuracy: 0.9382 - val_loss: 0.2293
# Epoch 91/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 11s 350ms/step - accuracy: 0.8724 - loss: 0.3893 - val_accuracy: 0.9382 - val_loss: 0.2087
# Epoch 92/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - accuracy: 0.8125 - loss: 0.6197 - val_accuracy: 0.9294 - val_loss: 0.2073
# Epoch 93/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 11s 342ms/step - accuracy: 0.8499 - loss: 0.4161 - val_accuracy: 0.9235 - val_loss: 0.2199
# Epoch 94/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - accuracy: 0.8125 - loss: 0.4484 - val_accuracy: 0.9324 - val_loss: 0.2103
# Epoch 95/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 11s 356ms/step - accuracy: 0.8715 - loss: 0.4218 - val_accuracy: 0.9206 - val_loss: 0.2460
# Epoch 96/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - accuracy: 0.9688 - loss: 0.2122 - val_accuracy: 0.9176 - val_loss: 0.2290
# Epoch 97/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 11s 346ms/step - accuracy: 0.8802 - loss: 0.3706 - val_accuracy: 0.9353 - val_loss: 0.2102
# Epoch 98/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - accuracy: 0.8125 - loss: 0.3477 - val_accuracy: 0.9324 - val_loss: 0.2129
# Epoch 99/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 11s 355ms/step - accuracy: 0.8740 - loss: 0.3953 - val_accuracy: 0.9235 - val_loss: 0.2332
# Epoch 100/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - accuracy: 0.7188 - loss: 0.7305 - val_accuracy: 0.9235 - val_loss: 0.2202

# %%
# evaluate the network
print("[INFO] evaluating network...")
predictions = model.predict(testx, batch_size=32)
print(classification_report(testy_encoded.argmax(axis=1),
                            predictions.argmax(axis=1), target_names=class_names))

# plot the performance
epochs = range(1, 101)
loss = H2.history['loss']
accuracy = H2.history['accuracy']
val_loss = H2.history['val_loss']
val_accuracy = H2.history['val_accuracy']
plot_df = pd.DataFrame(data=np.c_[epochs, loss, accuracy, val_loss, val_accuracy],
                       columns=['epochs', 'loss', 'accuracy', 'val_loss', 'val_accuracy'])

# do the actual plots
sns.set(font_scale=1)
f, ax = plt.subplots(1, 1, figsize=(15, 8))
sns.lineplot(data=plot_df, x='epochs', y='loss', ax=ax, label='train loss', linewidth=3)
sns.lineplot(data=plot_df, x='epochs', y='accuracy', ax=ax, label='train accuracy', linewidth=3)
sns.lineplot(data=plot_df, x='epochs', y='val_loss', ax=ax, label='val loss', linewidth=3)
sns.lineplot(data=plot_df, x='epochs', y='val_accuracy', ax=ax, label='val_accuracy', linewidth=3)
ax.set_ylabel('Loss or Accuracy')
ax.set_xlabel('Epochs')
# Out:
# [INFO] evaluating network...
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 207ms/step
#               precision    recall  f1-score   support
#
#     bluebell       0.95      0.95      0.95        20
#    buttercup       0.91      1.00      0.95        20
#    coltsfoot       0.88      0.88      0.88        16
#      cowslip       0.88      0.74      0.80        19
#       crocus       0.81      0.87      0.84        15
#     daffodil       0.86      0.90      0.88        20
#        daisy       1.00      0.83      0.90        23
#    dandelion       0.96      0.93      0.94        27
#   fritillary       0.95      1.00      0.97        19
#         iris       1.00      0.95      0.98        21
#   lilyvalley       0.94      0.94      0.94        18
#        pansy       0.94      1.00      0.97        16
#     snowdrop       0.87      0.91      0.89        22
#    sunflower       0.96      1.00      0.98        23
#    tigerlily       0.86      1.00      0.92        18
#        tulip       1.00      0.80      0.89        20
#   windflower       0.92      1.00      0.96        23
#
#     accuracy                           0.92       340
#    macro avg       0.92      0.92      0.92       340
# weighted avg       0.93      0.92      0.92       340
# Text(0.5, 0, 'Epochs')
