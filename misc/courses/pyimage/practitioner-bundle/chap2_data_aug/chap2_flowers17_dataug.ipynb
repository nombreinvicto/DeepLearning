# %%
import sys
from google.colab import drive

drive.mount('/content/drive')
sys.path.append(r"/content/drive/MyDrive/")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
! pip install -U opencv-python
! pip install colab-xterm
! pip install imutils
# Out:
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.11/dist-packages (4.12.0.88)
# Requirement already satisfied: numpy<2.3.0,>=2 in /usr/local/lib/python3.11/dist-packages (from opencv-python) (2.0.2)
# Requirement already satisfied: colab-xterm in /usr/local/lib/python3.11/dist-packages (0.2.0)
# Requirement already satisfied: ptyprocess~=0.7.0 in /usr/local/lib/python3.11/dist-packages (from colab-xterm) (0.7.0)
# Requirement already satisfied: tornado>5.1 in /usr/local/lib/python3.11/dist-packages (from colab-xterm) (6.4.2)
# Requirement already satisfied: imutils in /usr/local/lib/python3.11/dist-packages (0.5.4)

# %%
# import the necessary packages
from imutils import paths
from sklearn.preprocessing import LabelBinarizer, LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from loader_util.preprocessing import (ImageToArrayPreprocessor,
                                       AspectAwarePreprocessor,
                                       MeanPreprocessor)

from loader_util.datasets import SimpleDatasetLoader
from loader_util.nn.conv import MiniVGGNet
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import SGD

# %%
import sys, os, json
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
args = {
    "dataset": r"/content/drive/MyDrive/Colab Notebooks/ImageDataset/book2/flowers17"
}

# %%
print(f"[INFO] loading images......")
image_paths = list(paths.list_images(args["dataset"]))
class_names = [pt.split(os.path.sep)[-2] for pt in image_paths]
class_names = list(np.unique(class_names))
print(f"[INFO] found a total of {len(class_names)} classes with {len(image_paths)} images......")
# Out:
# [INFO] loading images......
# [INFO] found a total of 17 classes with 1360 images......

# %%
# construct the preprocessors
aap = AspectAwarePreprocessor(width=64, height=64)
iap = ImageToArrayPreprocessor()
sdl = SimpleDatasetLoader(preprocessors=[aap, iap])
data, labels = sdl.load(image_paths, verbose=500)
data = data.astype("float") / 255.0
trainx, testx, trainy, testy = train_test_split(data, labels, test_size=0.25, random_state=42)
# Out:
# [INFO] processed 500/1360
# [INFO] processed 1000/1360

# %%
# encode the labels numerically
lb = LabelBinarizer()
trainy = lb.fit_transform(trainy)
testy = lb.transform(testy)

# %%
# construct the image generator
aug = ImageDataGenerator(rotation_range=30,
                         width_shift_range=0.1,
                         height_shift_range=0.1,
                         shear_range=0.2,
                         zoom_range=0.2,
                         horizontal_flip=True,
                         fill_mode="nearest")

# %%
# compile the model
print(f"[INFO] compiling the model......")
opt = SGD(learning_rate=0.05)
model = MiniVGGNet.build(width=64,
                         height=64,
                         depth=3,
                         classes=len(class_names))
model.compile(loss="categorical_crossentropy",
              optimizer=opt,
              metrics=["accuracy"])
# Out:
# [INFO] compiling the model......
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
print(f"[INFO] training the network......")
BATCH_SIZE = 32
EPOCHS = 100
H = model.fit(aug.flow(trainx, trainy, batch_size=BATCH_SIZE),
              validation_data=(testx, testy),
              steps_per_epoch=len(trainx) // BATCH_SIZE,
              epochs=EPOCHS,
              verbose=1)
# Out:
# [INFO] training the network......
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 18s 297ms/step - accuracy: 0.1533 - loss: 3.8404 - val_accuracy: 0.1912 - val_loss: 3.2734
# Epoch 2/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.2188 - loss: 3.0164 - val_accuracy: 0.1647 - val_loss: 3.2713
# Epoch 3/100
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/epoch_iterator.py:107: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 6s 54ms/step - accuracy: 0.3670 - loss: 2.3180 - val_accuracy: 0.2676 - val_loss: 2.3981
# Epoch 4/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.3750 - loss: 2.2088 - val_accuracy: 0.2471 - val_loss: 2.4259
# Epoch 5/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - accuracy: 0.3807 - loss: 2.0841 - val_accuracy: 0.1882 - val_loss: 3.7025
# Epoch 6/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5000 - loss: 2.0812 - val_accuracy: 0.2118 - val_loss: 3.4251
# Epoch 7/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - accuracy: 0.4441 - loss: 1.9440 - val_accuracy: 0.2324 - val_loss: 2.7340
# Epoch 8/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5312 - loss: 1.5349 - val_accuracy: 0.2941 - val_loss: 2.5643
# Epoch 9/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - accuracy: 0.5166 - loss: 1.5733 - val_accuracy: 0.2882 - val_loss: 2.4745
# Epoch 10/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5312 - loss: 1.8851 - val_accuracy: 0.2441 - val_loss: 2.5739
# Epoch 11/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.5088 - loss: 1.5327 - val_accuracy: 0.4412 - val_loss: 1.7472
# Epoch 12/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6429 - loss: 1.3230 - val_accuracy: 0.3853 - val_loss: 1.9094
# Epoch 13/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - accuracy: 0.5430 - loss: 1.4476 - val_accuracy: 0.3324 - val_loss: 2.1757
# Epoch 14/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5312 - loss: 1.3879 - val_accuracy: 0.3147 - val_loss: 2.2538
# Epoch 15/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.5452 - loss: 1.4220 - val_accuracy: 0.3029 - val_loss: 2.3880
# Epoch 16/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5357 - loss: 1.6918 - val_accuracy: 0.3059 - val_loss: 2.2324
# Epoch 17/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.5372 - loss: 1.3705 - val_accuracy: 0.5676 - val_loss: 1.1913
# Epoch 18/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6250 - loss: 1.1484 - val_accuracy: 0.5735 - val_loss: 1.2020
# Epoch 19/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.5783 - loss: 1.3499 - val_accuracy: 0.6206 - val_loss: 1.2168
# Epoch 20/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5938 - loss: 1.2306 - val_accuracy: 0.5824 - val_loss: 1.2353
# Epoch 21/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - accuracy: 0.6064 - loss: 1.2080 - val_accuracy: 0.5059 - val_loss: 1.4907
# Epoch 22/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5938 - loss: 1.1004 - val_accuracy: 0.4735 - val_loss: 1.5527
# Epoch 23/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 61ms/step - accuracy: 0.6086 - loss: 1.2567 - val_accuracy: 0.5853 - val_loss: 1.2849
# Epoch 24/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.3750 - loss: 1.8338 - val_accuracy: 0.5588 - val_loss: 1.4670
# Epoch 25/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.5951 - loss: 1.1943 - val_accuracy: 0.4353 - val_loss: 1.9379
# Epoch 26/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5000 - loss: 1.6271 - val_accuracy: 0.5853 - val_loss: 1.2975
# Epoch 27/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - accuracy: 0.6418 - loss: 1.0400 - val_accuracy: 0.5412 - val_loss: 1.4424
# Epoch 28/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7188 - loss: 0.9191 - val_accuracy: 0.5559 - val_loss: 1.4293
# Epoch 29/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.6148 - loss: 1.1761 - val_accuracy: 0.6324 - val_loss: 1.0907
# Epoch 30/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6250 - loss: 1.1575 - val_accuracy: 0.6176 - val_loss: 1.0964
# Epoch 31/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.6278 - loss: 1.1122 - val_accuracy: 0.6824 - val_loss: 1.0297
# Epoch 32/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5938 - loss: 0.9888 - val_accuracy: 0.6588 - val_loss: 1.0032
# Epoch 33/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.6707 - loss: 0.9815 - val_accuracy: 0.6324 - val_loss: 1.1795
# Epoch 34/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8438 - loss: 0.5337 - val_accuracy: 0.6324 - val_loss: 1.2115
# Epoch 35/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - accuracy: 0.6909 - loss: 0.9008 - val_accuracy: 0.6559 - val_loss: 1.2172
# Epoch 36/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5357 - loss: 1.2461 - val_accuracy: 0.6294 - val_loss: 1.2006
# Epoch 37/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 0.6519 - loss: 1.0431 - val_accuracy: 0.6176 - val_loss: 1.1143
# Epoch 38/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6562 - loss: 1.3130 - val_accuracy: 0.6088 - val_loss: 1.2595
# Epoch 39/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - accuracy: 0.6879 - loss: 0.8878 - val_accuracy: 0.6000 - val_loss: 1.2651
# Epoch 40/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5938 - loss: 1.0965 - val_accuracy: 0.5941 - val_loss: 1.3203
# Epoch 41/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - accuracy: 0.7173 - loss: 0.9180 - val_accuracy: 0.6529 - val_loss: 1.1866
# Epoch 42/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6250 - loss: 0.9499 - val_accuracy: 0.6088 - val_loss: 1.2730
# Epoch 43/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.7121 - loss: 0.8989 - val_accuracy: 0.6706 - val_loss: 1.1058
# Epoch 44/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7812 - loss: 0.8455 - val_accuracy: 0.6647 - val_loss: 1.0866
# Epoch 45/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - accuracy: 0.7248 - loss: 0.8238 - val_accuracy: 0.6588 - val_loss: 1.1121
# Epoch 46/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7812 - loss: 0.8717 - val_accuracy: 0.6765 - val_loss: 1.0698
# Epoch 47/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - accuracy: 0.7099 - loss: 0.8662 - val_accuracy: 0.5941 - val_loss: 1.3135
# Epoch 48/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6429 - loss: 0.9916 - val_accuracy: 0.6559 - val_loss: 1.1519
# Epoch 49/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.7103 - loss: 0.8779 - val_accuracy: 0.6529 - val_loss: 1.2178
# Epoch 50/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6562 - loss: 0.8110 - val_accuracy: 0.6353 - val_loss: 1.2744
# Epoch 51/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - accuracy: 0.7054 - loss: 0.9111 - val_accuracy: 0.5971 - val_loss: 1.4396
# Epoch 52/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5000 - loss: 1.3113 - val_accuracy: 0.6588 - val_loss: 1.1122
# Epoch 53/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - accuracy: 0.7357 - loss: 0.7998 - val_accuracy: 0.6441 - val_loss: 1.2163
# Epoch 54/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6250 - loss: 1.0854 - val_accuracy: 0.6706 - val_loss: 1.1326
# Epoch 55/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - accuracy: 0.7300 - loss: 0.7533 - val_accuracy: 0.6647 - val_loss: 1.1482
# Epoch 56/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9688 - loss: 0.2554 - val_accuracy: 0.6206 - val_loss: 1.2580
# Epoch 57/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.7332 - loss: 0.7520 - val_accuracy: 0.7206 - val_loss: 1.0485
# Epoch 58/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6875 - loss: 0.6846 - val_accuracy: 0.6735 - val_loss: 1.1571
# Epoch 59/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - accuracy: 0.7615 - loss: 0.7432 - val_accuracy: 0.6206 - val_loss: 1.4163
# Epoch 60/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6562 - loss: 1.0683 - val_accuracy: 0.6588 - val_loss: 1.1696
# Epoch 61/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 0.7926 - loss: 0.6730 - val_accuracy: 0.7029 - val_loss: 1.0432
# Epoch 62/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5938 - loss: 1.0737 - val_accuracy: 0.6588 - val_loss: 1.2051
# Epoch 63/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.7563 - loss: 0.7052 - val_accuracy: 0.6676 - val_loss: 1.2059
# Epoch 64/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7812 - loss: 0.6439 - val_accuracy: 0.6588 - val_loss: 1.2141
# Epoch 65/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - accuracy: 0.7756 - loss: 0.7045 - val_accuracy: 0.6941 - val_loss: 1.1111
# Epoch 66/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6562 - loss: 0.9782 - val_accuracy: 0.6529 - val_loss: 1.3077
# Epoch 67/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.7661 - loss: 0.6714 - val_accuracy: 0.6853 - val_loss: 1.0755
# Epoch 68/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6875 - loss: 0.8221 - val_accuracy: 0.6529 - val_loss: 1.1710
# Epoch 69/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - accuracy: 0.7982 - loss: 0.6054 - val_accuracy: 0.6294 - val_loss: 1.3896
# Epoch 70/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8125 - loss: 0.5869 - val_accuracy: 0.6853 - val_loss: 1.1370
# Epoch 71/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - accuracy: 0.7687 - loss: 0.7269 - val_accuracy: 0.6941 - val_loss: 1.0263
# Epoch 72/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5938 - loss: 0.8103 - val_accuracy: 0.7029 - val_loss: 0.9842
# Epoch 73/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - accuracy: 0.7665 - loss: 0.7547 - val_accuracy: 0.6706 - val_loss: 1.1111
# Epoch 74/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6250 - loss: 0.7026 - val_accuracy: 0.6824 - val_loss: 1.1329
# Epoch 75/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 0.8029 - loss: 0.5936 - val_accuracy: 0.7294 - val_loss: 0.9585
# Epoch 76/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8750 - loss: 0.5421 - val_accuracy: 0.7029 - val_loss: 1.0170
# Epoch 77/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 0.7909 - loss: 0.5889 - val_accuracy: 0.6941 - val_loss: 1.1088
# Epoch 78/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6875 - loss: 0.7699 - val_accuracy: 0.7000 - val_loss: 1.0727
# Epoch 79/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - accuracy: 0.7984 - loss: 0.6020 - val_accuracy: 0.6382 - val_loss: 1.2453
# Epoch 80/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6875 - loss: 0.9518 - val_accuracy: 0.6382 - val_loss: 1.4461
# Epoch 81/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - accuracy: 0.7677 - loss: 0.6413 - val_accuracy: 0.7265 - val_loss: 1.0697
# Epoch 82/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9062 - loss: 0.3076 - val_accuracy: 0.7353 - val_loss: 1.0255
# Epoch 83/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - accuracy: 0.7837 - loss: 0.6832 - val_accuracy: 0.6235 - val_loss: 1.3954
# Epoch 84/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5625 - loss: 1.0201 - val_accuracy: 0.6088 - val_loss: 1.2671
# Epoch 85/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - accuracy: 0.8066 - loss: 0.5293 - val_accuracy: 0.6706 - val_loss: 1.0951
# Epoch 86/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8438 - loss: 0.4115 - val_accuracy: 0.6941 - val_loss: 1.0255
# Epoch 87/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - accuracy: 0.7968 - loss: 0.6086 - val_accuracy: 0.6676 - val_loss: 1.3207
# Epoch 88/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8438 - loss: 0.4440 - val_accuracy: 0.6912 - val_loss: 1.1874
# Epoch 89/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - accuracy: 0.8006 - loss: 0.5772 - val_accuracy: 0.6824 - val_loss: 1.1037
# Epoch 90/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7500 - loss: 0.4786 - val_accuracy: 0.6235 - val_loss: 1.3706
# Epoch 91/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - accuracy: 0.7978 - loss: 0.6055 - val_accuracy: 0.7353 - val_loss: 0.9902
# Epoch 92/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8750 - loss: 0.3757 - val_accuracy: 0.7294 - val_loss: 0.9827
# Epoch 93/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 66ms/step - accuracy: 0.8177 - loss: 0.5374 - val_accuracy: 0.7088 - val_loss: 1.1275
# Epoch 94/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8438 - loss: 0.6806 - val_accuracy: 0.7206 - val_loss: 1.1035
# Epoch 95/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 63ms/step - accuracy: 0.7743 - loss: 0.6714 - val_accuracy: 0.7059 - val_loss: 1.0587
# Epoch 96/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8125 - loss: 0.5788 - val_accuracy: 0.7206 - val_loss: 1.0151
# Epoch 97/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.8365 - loss: 0.4686 - val_accuracy: 0.7147 - val_loss: 1.0847
# Epoch 98/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8750 - loss: 0.4172 - val_accuracy: 0.6912 - val_loss: 1.1316
# Epoch 99/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.7989 - loss: 0.5689 - val_accuracy: 0.7118 - val_loss: 1.1216
# Epoch 100/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8750 - loss: 0.5647 - val_accuracy: 0.6941 - val_loss: 1.1702

# %%
print("[INFO] evaluating network...")
predictions = model.predict(testx, batch_size=BATCH_SIZE)
print(classification_report(testy.argmax(axis=1),
                            predictions.argmax(axis=1), target_names=class_names))

# plot the performance
epochs = range(1, EPOCHS + 1)
loss = H.history['loss']
accuracy = H.history['accuracy']
val_loss = H.history['val_loss']
val_accuracy = H.history['val_accuracy']
plot_df = pd.DataFrame(data=np.c_[epochs, loss, accuracy, val_loss, val_accuracy],
                       columns=['epochs', 'loss', 'accuracy', 'val_loss', 'val_accuracy'])

# do the actual plots
sns.set(font_scale=1)
f, ax = plt.subplots(1, 1, figsize=(12, 6))
sns.lineplot(data=plot_df, x='epochs', y='loss', ax=ax, label='train loss', linewidth=3)
sns.lineplot(data=plot_df, x='epochs', y='accuracy', ax=ax, label='train accuracy', linewidth=3)
sns.lineplot(data=plot_df, x='epochs', y='val_loss', ax=ax, label='val loss', linewidth=3)
sns.lineplot(data=plot_df, x='epochs', y='val_accuracy', ax=ax, label='val_accuracy', linewidth=3)
ax.set_ylabel('Loss or Accuracy')
ax.set_xlabel('Epochs')
# Out:
# [INFO] evaluating network...
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
#               precision    recall  f1-score   support
#
#     bluebell       0.77      0.85      0.81        20
#    buttercup       0.72      0.90      0.80        20
#    coltsfoot       0.48      0.69      0.56        16
#      cowslip       0.47      0.74      0.57        19
#       crocus       0.75      0.60      0.67        15
#     daffodil       0.50      0.30      0.38        20
#        daisy       0.85      0.74      0.79        23
#    dandelion       0.82      0.52      0.64        27
#   fritillary       0.89      0.89      0.89        19
#         iris       1.00      0.67      0.80        21
#   lilyvalley       0.59      0.72      0.65        18
#        pansy       1.00      0.62      0.77        16
#     snowdrop       0.47      0.68      0.56        22
#    sunflower       1.00      0.91      0.95        23
#    tigerlily       0.85      0.94      0.89        18
#        tulip       0.36      0.20      0.26        20
#   windflower       0.63      0.83      0.72        23
#
#     accuracy                           0.69       340
#    macro avg       0.72      0.69      0.69       340
# weighted avg       0.72      0.69      0.69       340
# Text(0.5, 0, 'Epochs')
