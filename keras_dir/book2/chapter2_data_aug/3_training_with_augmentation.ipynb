# %%
! pip install opencv-python==4.5.5.64
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting opencv-python==4.5.5.64
#   Downloading opencv_python-4.5.5.64-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (60.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.5/60.5 MB 9.1 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.10/dist-packages (from opencv-python==4.5.5.64) (1.22.4)
# Installing collected packages: opencv-python
#   Attempting uninstall: opencv-python
#     Found existing installation: opencv-python 4.7.0.72
#     Uninstalling opencv-python-4.7.0.72:
#       Successfully uninstalled opencv-python-4.7.0.72
# Successfully installed opencv-python-4.5.5.64

# %%
import sys
from google.colab import drive
drive.mount('/content/drive')
sys.path.append(r"/content/drive/MyDrive/")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import sys, os, json
import numpy as np
import pandas as pd
import seaborn as sns
import argparse, progressbar
import matplotlib.pyplot as plt
from matplotlib.figure import Figure
from matplotlib.axes import Axes
sns.set()

# %%
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from loader_util.preprocessing import ImageToArrayPreprocessor
from loader_util.preprocessing import AspectAwarePreprocessor
from loader_util.datasets import SimpleDatasetLoader
from loader_util.nn.conv import MinVGGNet
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import SGD
from imutils import paths

# %%
# script constants
dataset_path = r"/content/drive/MyDrive/Colab Notebooks/ImageDataset/book2/flowers17/images"
n_epochs = 100
batch_size = 32

# %%
print(f"[INFO] loading images......")
image_paths = list(paths.list_images(dataset_path))
class_names = [pth.split(os.path.sep)[-2] for pth in image_paths]
print(len(class_names))
class_names = list(np.unique(class_names))
class_names
# Out:
# [INFO] loading images......
# 1360
# ['bluebell',
#  'buttercup',
#  'coltsfoot',
#  'cowslip',
#  'crocus',
#  'daffodil',
#  'daisy',
#  'dandelion',
#  'fritillary',
#  'iris',
#  'lilyvalley',
#  'pansy',
#  'snowdrop',
#  'sunflower',
#  'tigerlily',
#  'tulip',
#  'windflower']

# %%
# init the preprocessors, loaders and load the data
aap = AspectAwarePreprocessor(64, 64)
iap = ImageToArrayPreprocessor()
sdl = SimpleDatasetLoader(preprocessors=[aap, iap])
data, labels = sdl.load(image_paths, verbose=500)
data = data.astype("float") / 255.0

# now split the data
trainx, testx, trainy, testy = train_test_split(data, labels,
                                                test_size=0.25,
                                                random_state=42)

# encode the labels
lb = LabelBinarizer()
trainy = lb.fit_transform(trainy)
testy = lb.transform(testy)
# Out:
# [INFO] processed 500/1360
# [INFO] processed 1000/1360

# %%
# construct the data augmentation generator
aug = ImageDataGenerator(rotation_range=30,
                         width_shift_range=0.1,
                         height_shift_range=0.1,
                         shear_range=0.2,
                         zoom_range=0.2,
                         horizontal_flip=True,
                         fill_mode="nearest")

# %%
# init the optimizer model
print(f"[INFO] compiling model......")
opt = SGD(learning_rate=0.05)
model = MinVGGNet.build(width=64,
                        height=64,
                        depth=3,
                        classes=len(class_names))
model.compile(loss="categorical_crossentropy",
              optimizer=opt,
              metrics=["accuracy"])
# Out:
# [INFO] compiling model......

# %%
print(f"[INFO] training network......")
H = model.fit_generator(aug.flow(trainx, trainy, batch_size=batch_size),
                        validation_data=(testx, testy),
                        steps_per_epoch=len(trainx) // batch_size,
                        epochs=n_epochs,
                        verbose=1)
# Out:
# [INFO] training network......
# Epoch 1/100
# <ipython-input-10-11492991258a>:2: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   H = model.fit_generator(aug.flow(trainx, trainy, batch_size=batch_size),
# 31/31 [==============================] - 14s 93ms/step - loss: 3.6093 - accuracy: 0.1761 - val_loss: 6.1545 - val_accuracy: 0.0824
# Epoch 2/100
# 31/31 [==============================] - 2s 61ms/step - loss: 2.6335 - accuracy: 0.3036 - val_loss: 2.7053 - val_accuracy: 0.2265
# Epoch 3/100
# 31/31 [==============================] - 2s 68ms/step - loss: 2.2826 - accuracy: 0.3462 - val_loss: 2.3753 - val_accuracy: 0.2912
# Epoch 4/100
# 31/31 [==============================] - 2s 49ms/step - loss: 2.0271 - accuracy: 0.3927 - val_loss: 2.9338 - val_accuracy: 0.2412
# Epoch 5/100
# 31/31 [==============================] - 1s 46ms/step - loss: 1.7429 - accuracy: 0.4656 - val_loss: 2.8605 - val_accuracy: 0.2029
# Epoch 6/100
# 31/31 [==============================] - 1s 46ms/step - loss: 1.7317 - accuracy: 0.4676 - val_loss: 2.3247 - val_accuracy: 0.2882
# Epoch 7/100
# 31/31 [==============================] - 2s 49ms/step - loss: 1.5721 - accuracy: 0.4929 - val_loss: 2.4646 - val_accuracy: 0.3147
# Epoch 8/100
# 31/31 [==============================] - 2s 60ms/step - loss: 1.4957 - accuracy: 0.5101 - val_loss: 1.7611 - val_accuracy: 0.4206
# Epoch 9/100
# 31/31 [==============================] - 2s 70ms/step - loss: 1.4474 - accuracy: 0.5223 - val_loss: 1.8056 - val_accuracy: 0.4324
# Epoch 10/100
# 31/31 [==============================] - 1s 46ms/step - loss: 1.3212 - accuracy: 0.5638 - val_loss: 2.4694 - val_accuracy: 0.3735
# Epoch 11/100
# 31/31 [==============================] - 1s 47ms/step - loss: 1.4031 - accuracy: 0.5567 - val_loss: 1.3785 - val_accuracy: 0.5794
# Epoch 12/100
# 31/31 [==============================] - 1s 46ms/step - loss: 1.4127 - accuracy: 0.5445 - val_loss: 1.4847 - val_accuracy: 0.5618
# Epoch 13/100
# 31/31 [==============================] - 1s 46ms/step - loss: 1.2701 - accuracy: 0.5941 - val_loss: 1.2837 - val_accuracy: 0.5941
# Epoch 14/100
# 31/31 [==============================] - 2s 77ms/step - loss: 1.2632 - accuracy: 0.5759 - val_loss: 1.3077 - val_accuracy: 0.6206
# Epoch 15/100
# 31/31 [==============================] - 2s 65ms/step - loss: 1.1837 - accuracy: 0.6123 - val_loss: 1.2210 - val_accuracy: 0.5912
# Epoch 16/100
# 31/31 [==============================] - 1s 47ms/step - loss: 1.2422 - accuracy: 0.6053 - val_loss: 1.2535 - val_accuracy: 0.6059
# Epoch 17/100
# 31/31 [==============================] - 1s 47ms/step - loss: 1.2190 - accuracy: 0.5901 - val_loss: 1.1836 - val_accuracy: 0.6588
# Epoch 18/100
# 31/31 [==============================] - 1s 46ms/step - loss: 1.1323 - accuracy: 0.6215 - val_loss: 1.3585 - val_accuracy: 0.5971
# Epoch 19/100
# 31/31 [==============================] - 1s 46ms/step - loss: 1.0923 - accuracy: 0.6265 - val_loss: 1.2989 - val_accuracy: 0.6265
# Epoch 20/100
# 31/31 [==============================] - 2s 49ms/step - loss: 1.1236 - accuracy: 0.6285 - val_loss: 1.1903 - val_accuracy: 0.6529
# Epoch 21/100
# 31/31 [==============================] - 2s 71ms/step - loss: 1.0988 - accuracy: 0.6538 - val_loss: 1.2932 - val_accuracy: 0.6088
# Epoch 22/100
# 31/31 [==============================] - 1s 46ms/step - loss: 1.0439 - accuracy: 0.6741 - val_loss: 1.1972 - val_accuracy: 0.6441
# Epoch 23/100
# 31/31 [==============================] - 1s 46ms/step - loss: 1.0132 - accuracy: 0.6569 - val_loss: 1.3613 - val_accuracy: 0.5971
# Epoch 24/100
# 31/31 [==============================] - 1s 46ms/step - loss: 1.0164 - accuracy: 0.6650 - val_loss: 1.1077 - val_accuracy: 0.6500
# Epoch 25/100
# 31/31 [==============================] - 1s 45ms/step - loss: 0.9609 - accuracy: 0.6711 - val_loss: 1.2097 - val_accuracy: 0.6559
# Epoch 26/100
# 31/31 [==============================] - 1s 46ms/step - loss: 0.9435 - accuracy: 0.6852 - val_loss: 1.2102 - val_accuracy: 0.6794
# Epoch 27/100
# 31/31 [==============================] - 2s 52ms/step - loss: 0.9651 - accuracy: 0.6933 - val_loss: 1.4058 - val_accuracy: 0.5971
# Epoch 28/100
# 31/31 [==============================] - 2s 79ms/step - loss: 0.9539 - accuracy: 0.6781 - val_loss: 1.1051 - val_accuracy: 0.6559
# Epoch 29/100
# 31/31 [==============================] - 2s 57ms/step - loss: 0.8901 - accuracy: 0.7004 - val_loss: 1.0662 - val_accuracy: 0.6559
# Epoch 30/100
# 31/31 [==============================] - 2s 49ms/step - loss: 0.9237 - accuracy: 0.6842 - val_loss: 1.0283 - val_accuracy: 0.6529
# Epoch 31/100
# 31/31 [==============================] - 1s 45ms/step - loss: 0.8432 - accuracy: 0.7085 - val_loss: 1.1093 - val_accuracy: 0.6794
# Epoch 32/100
# 31/31 [==============================] - 1s 45ms/step - loss: 0.8465 - accuracy: 0.7105 - val_loss: 1.3679 - val_accuracy: 0.6000
# Epoch 33/100
# 31/31 [==============================] - 2s 50ms/step - loss: 0.8794 - accuracy: 0.6923 - val_loss: 1.0474 - val_accuracy: 0.6588
# Epoch 34/100
# 31/31 [==============================] - 2s 56ms/step - loss: 0.8396 - accuracy: 0.7055 - val_loss: 1.1263 - val_accuracy: 0.6500
# Epoch 35/100
# 31/31 [==============================] - 2s 78ms/step - loss: 0.8146 - accuracy: 0.7176 - val_loss: 1.1074 - val_accuracy: 0.6912
# Epoch 36/100
# 31/31 [==============================] - 2s 49ms/step - loss: 0.7945 - accuracy: 0.7389 - val_loss: 1.0140 - val_accuracy: 0.6765
# Epoch 37/100
# 31/31 [==============================] - 1s 45ms/step - loss: 0.8447 - accuracy: 0.7085 - val_loss: 1.0459 - val_accuracy: 0.6706
# Epoch 38/100
# 31/31 [==============================] - 1s 46ms/step - loss: 0.8500 - accuracy: 0.7095 - val_loss: 1.3004 - val_accuracy: 0.6029
# Epoch 39/100
# 31/31 [==============================] - 1s 47ms/step - loss: 0.7127 - accuracy: 0.7551 - val_loss: 1.0794 - val_accuracy: 0.6588
# Epoch 40/100
# 31/31 [==============================] - 1s 46ms/step - loss: 0.7511 - accuracy: 0.7419 - val_loss: 0.9766 - val_accuracy: 0.6853
# Epoch 41/100
# 31/31 [==============================] - 2s 59ms/step - loss: 0.7910 - accuracy: 0.7308 - val_loss: 1.1934 - val_accuracy: 0.6735
# Epoch 42/100
# 31/31 [==============================] - 2s 67ms/step - loss: 0.7966 - accuracy: 0.7186 - val_loss: 1.2685 - val_accuracy: 0.6382
# Epoch 43/100
# 31/31 [==============================] - 2s 48ms/step - loss: 0.6961 - accuracy: 0.7591 - val_loss: 1.0364 - val_accuracy: 0.6882
# Epoch 44/100
# 31/31 [==============================] - 1s 47ms/step - loss: 0.7639 - accuracy: 0.7490 - val_loss: 1.0599 - val_accuracy: 0.6794
# Epoch 45/100
# 31/31 [==============================] - 1s 46ms/step - loss: 0.6720 - accuracy: 0.7713 - val_loss: 1.0171 - val_accuracy: 0.6853
# Epoch 46/100
# 31/31 [==============================] - 1s 46ms/step - loss: 0.6271 - accuracy: 0.7773 - val_loss: 1.0193 - val_accuracy: 0.6912
# Epoch 47/100
# 31/31 [==============================] - 1s 47ms/step - loss: 0.6436 - accuracy: 0.7773 - val_loss: 1.0288 - val_accuracy: 0.6853
# Epoch 48/100
# 31/31 [==============================] - 2s 60ms/step - loss: 0.6969 - accuracy: 0.7551 - val_loss: 1.0260 - val_accuracy: 0.6941
# Epoch 49/100
# 31/31 [==============================] - 3s 82ms/step - loss: 0.6231 - accuracy: 0.7834 - val_loss: 1.0387 - val_accuracy: 0.6941
# Epoch 50/100
# 31/31 [==============================] - 1s 47ms/step - loss: 0.6229 - accuracy: 0.7895 - val_loss: 1.0071 - val_accuracy: 0.7029
# Epoch 51/100
# 31/31 [==============================] - 1s 46ms/step - loss: 0.6590 - accuracy: 0.7753 - val_loss: 1.0512 - val_accuracy: 0.6735
# Epoch 52/100
# 31/31 [==============================] - 1s 46ms/step - loss: 0.6275 - accuracy: 0.7814 - val_loss: 1.0571 - val_accuracy: 0.7235
# Epoch 53/100
# 31/31 [==============================] - 1s 47ms/step - loss: 0.6134 - accuracy: 0.7986 - val_loss: 0.9431 - val_accuracy: 0.7147
# Epoch 54/100
# 31/31 [==============================] - 3s 80ms/step - loss: 0.6234 - accuracy: 0.7955 - val_loss: 1.0460 - val_accuracy: 0.7235
# Epoch 55/100
# 31/31 [==============================] - 2s 50ms/step - loss: 0.5557 - accuracy: 0.8036 - val_loss: 0.9953 - val_accuracy: 0.6971
# Epoch 56/100
# 31/31 [==============================] - 1s 46ms/step - loss: 0.5511 - accuracy: 0.8026 - val_loss: 1.0501 - val_accuracy: 0.6971
# Epoch 57/100
# 31/31 [==============================] - 1s 46ms/step - loss: 0.5483 - accuracy: 0.8057 - val_loss: 1.1760 - val_accuracy: 0.6765
# Epoch 58/100
# 31/31 [==============================] - 2s 51ms/step - loss: 0.6566 - accuracy: 0.7844 - val_loss: 1.0415 - val_accuracy: 0.6676
# Epoch 59/100
# 31/31 [==============================] - 2s 48ms/step - loss: 0.6021 - accuracy: 0.7854 - val_loss: 1.1869 - val_accuracy: 0.6735
# Epoch 60/100
# 31/31 [==============================] - 2s 63ms/step - loss: 0.5762 - accuracy: 0.8026 - val_loss: 1.0513 - val_accuracy: 0.6912
# Epoch 61/100
# 31/31 [==============================] - 2s 78ms/step - loss: 0.5364 - accuracy: 0.8198 - val_loss: 1.3768 - val_accuracy: 0.6353
# Epoch 62/100
# 31/31 [==============================] - 1s 46ms/step - loss: 0.5277 - accuracy: 0.8259 - val_loss: 1.0444 - val_accuracy: 0.6853
# Epoch 63/100
# 31/31 [==============================] - 1s 47ms/step - loss: 0.5680 - accuracy: 0.8097 - val_loss: 1.0078 - val_accuracy: 0.6676
# Epoch 64/100
# 31/31 [==============================] - 1s 47ms/step - loss: 0.5381 - accuracy: 0.8117 - val_loss: 0.9813 - val_accuracy: 0.7059
# Epoch 65/100
# 31/31 [==============================] - 1s 46ms/step - loss: 0.5327 - accuracy: 0.8300 - val_loss: 1.2889 - val_accuracy: 0.6676
# Epoch 66/100
# 31/31 [==============================] - 2s 57ms/step - loss: 0.5373 - accuracy: 0.8117 - val_loss: 0.9353 - val_accuracy: 0.7118
# Epoch 67/100
# 31/31 [==============================] - 3s 80ms/step - loss: 0.5704 - accuracy: 0.7976 - val_loss: 1.0510 - val_accuracy: 0.7265
# Epoch 68/100
# 31/31 [==============================] - 2s 49ms/step - loss: 0.5800 - accuracy: 0.7976 - val_loss: 1.2096 - val_accuracy: 0.6941
# Epoch 69/100
# 31/31 [==============================] - 1s 47ms/step - loss: 0.5425 - accuracy: 0.8178 - val_loss: 1.1098 - val_accuracy: 0.6824
# Epoch 70/100
# 31/31 [==============================] - 2s 51ms/step - loss: 0.4769 - accuracy: 0.8441 - val_loss: 1.0462 - val_accuracy: 0.7235
# Epoch 71/100
# 31/31 [==============================] - 2s 49ms/step - loss: 0.4927 - accuracy: 0.8317 - val_loss: 0.9761 - val_accuracy: 0.7118
# Epoch 72/100
# 31/31 [==============================] - 1s 47ms/step - loss: 0.4861 - accuracy: 0.8300 - val_loss: 1.0321 - val_accuracy: 0.6971
# Epoch 73/100
# 31/31 [==============================] - 2s 77ms/step - loss: 0.4795 - accuracy: 0.8320 - val_loss: 0.9788 - val_accuracy: 0.7176
# Epoch 74/100
# 31/31 [==============================] - 2s 54ms/step - loss: 0.4394 - accuracy: 0.8411 - val_loss: 1.0532 - val_accuracy: 0.7029
# Epoch 75/100
# 31/31 [==============================] - 1s 47ms/step - loss: 0.4667 - accuracy: 0.8269 - val_loss: 1.0028 - val_accuracy: 0.7029
# Epoch 76/100
# 31/31 [==============================] - 1s 46ms/step - loss: 0.3989 - accuracy: 0.8573 - val_loss: 0.9715 - val_accuracy: 0.7412
# Epoch 77/100
# 31/31 [==============================] - 1s 47ms/step - loss: 0.4059 - accuracy: 0.8654 - val_loss: 0.9680 - val_accuracy: 0.7176
# Epoch 78/100
# 31/31 [==============================] - 1s 47ms/step - loss: 0.4778 - accuracy: 0.8391 - val_loss: 1.0934 - val_accuracy: 0.6941
# Epoch 79/100
# 31/31 [==============================] - 2s 50ms/step - loss: 0.4160 - accuracy: 0.8563 - val_loss: 1.1643 - val_accuracy: 0.6765
# Epoch 80/100
# 31/31 [==============================] - 3s 81ms/step - loss: 0.4501 - accuracy: 0.8431 - val_loss: 1.1355 - val_accuracy: 0.7206
# Epoch 81/100
# 31/31 [==============================] - 1s 47ms/step - loss: 0.4306 - accuracy: 0.8482 - val_loss: 0.9961 - val_accuracy: 0.7147
# Epoch 82/100
# 31/31 [==============================] - 1s 48ms/step - loss: 0.3762 - accuracy: 0.8654 - val_loss: 1.1159 - val_accuracy: 0.7029
# Epoch 83/100
# 31/31 [==============================] - 2s 48ms/step - loss: 0.5363 - accuracy: 0.7976 - val_loss: 1.1519 - val_accuracy: 0.6941
# Epoch 84/100
# 31/31 [==============================] - 1s 47ms/step - loss: 0.4616 - accuracy: 0.8563 - val_loss: 1.0514 - val_accuracy: 0.7265
# Epoch 85/100
# 31/31 [==============================] - 2s 62ms/step - loss: 0.4599 - accuracy: 0.8391 - val_loss: 1.0828 - val_accuracy: 0.7059
# Epoch 86/100
# 31/31 [==============================] - 2s 78ms/step - loss: 0.4068 - accuracy: 0.8543 - val_loss: 1.0467 - val_accuracy: 0.7059
# Epoch 87/100
# 31/31 [==============================] - 2s 51ms/step - loss: 0.4373 - accuracy: 0.8532 - val_loss: 0.9632 - val_accuracy: 0.7206
# Epoch 88/100
# 31/31 [==============================] - 1s 48ms/step - loss: 0.3379 - accuracy: 0.8806 - val_loss: 1.0990 - val_accuracy: 0.6971
# Epoch 89/100
# 31/31 [==============================] - 1s 47ms/step - loss: 0.3758 - accuracy: 0.8654 - val_loss: 0.9531 - val_accuracy: 0.7324
# Epoch 90/100
# 31/31 [==============================] - 1s 46ms/step - loss: 0.4513 - accuracy: 0.8482 - val_loss: 0.9943 - val_accuracy: 0.7059
# Epoch 91/100
# 31/31 [==============================] - 1s 47ms/step - loss: 0.4293 - accuracy: 0.8543 - val_loss: 1.0553 - val_accuracy: 0.7294
# Epoch 92/100
# 31/31 [==============================] - 2s 49ms/step - loss: 0.3607 - accuracy: 0.8816 - val_loss: 0.9982 - val_accuracy: 0.7118
# Epoch 93/100
# 31/31 [==============================] - 2s 79ms/step - loss: 0.3669 - accuracy: 0.8715 - val_loss: 1.1299 - val_accuracy: 0.7029
# Epoch 94/100
# 31/31 [==============================] - 2s 49ms/step - loss: 0.3383 - accuracy: 0.8735 - val_loss: 1.1718 - val_accuracy: 0.6882
# Epoch 95/100
# 31/31 [==============================] - 1s 47ms/step - loss: 0.3363 - accuracy: 0.8861 - val_loss: 1.1471 - val_accuracy: 0.7176
# Epoch 96/100
# 31/31 [==============================] - 2s 48ms/step - loss: 0.3615 - accuracy: 0.8715 - val_loss: 1.0721 - val_accuracy: 0.6971
# Epoch 97/100
# 31/31 [==============================] - 1s 48ms/step - loss: 0.3751 - accuracy: 0.8806 - val_loss: 1.0549 - val_accuracy: 0.7206
# Epoch 98/100
# 31/31 [==============================] - 1s 47ms/step - loss: 0.3012 - accuracy: 0.8947 - val_loss: 1.1104 - val_accuracy: 0.7118
# Epoch 99/100
# 31/31 [==============================] - 2s 68ms/step - loss: 0.4014 - accuracy: 0.8613 - val_loss: 1.0924 - val_accuracy: 0.6971
# Epoch 100/100
# 31/31 [==============================] - 2s 79ms/step - loss: 0.3450 - accuracy: 0.8796 - val_loss: 0.9265 - val_accuracy: 0.7324

# %%
# evaluate the network
print ( "[INFO] evaluating network..." )
predictions = model.predict(testx, batch_size=32 )
print (classification_report(testy.argmax(axis=1 ),
predictions.argmax(axis=1 ), target_names=class_names))


# plot the performance
epochs = range(1,n_epochs+1)
loss = H.history['loss']
accuracy = H.history['accuracy']
val_loss = H.history['val_loss']
val_accuracy = H.history['val_accuracy']
plot_df = pd.DataFrame(data=np.c_[epochs,loss,accuracy,val_loss,val_accuracy],
                       columns=['epochs','loss', 'accuracy', 'val_loss', 'val_accuracy'])

# do the actual plots
sns.set(font_scale=1)
f, ax = plt.subplots(1, 1, figsize=(15,8))
sns.lineplot(data=plot_df, x='epochs', y='loss', ax=ax, label='train loss', linewidth=3)
sns.lineplot(data=plot_df, x='epochs', y='accuracy', ax=ax, label='train accuracy', linewidth=3)
sns.lineplot(data=plot_df, x='epochs', y='val_loss', ax=ax, label='val loss', linewidth=3)
sns.lineplot(data=plot_df, x='epochs', y='val_accuracy', ax=ax, label='val_accuracy', linewidth=3)
ax.set_ylabel('Loss or Accuracy')
ax.set_xlabel('Epochs')
plt.setp(ax.get_legend().get_texts(), fontsize='18'); # for legend text
# Out:
# [INFO] evaluating network...
# 11/11 [==============================] - 0s 5ms/step
#               precision    recall  f1-score   support
#
#     bluebell       0.70      0.95      0.81        20
#    buttercup       0.59      0.80      0.68        20
#    coltsfoot       0.52      0.81      0.63        16
#      cowslip       0.70      0.74      0.72        19
#       crocus       0.39      0.47      0.42        15
#     daffodil       0.56      0.45      0.50        20
#        daisy       0.79      0.83      0.81        23
#    dandelion       0.94      0.63      0.76        27
#   fritillary       0.89      0.84      0.86        19
#         iris       1.00      0.81      0.89        21
#   lilyvalley       0.74      0.78      0.76        18
#        pansy       0.92      0.75      0.83        16
#     snowdrop       0.74      0.77      0.76        22
#    sunflower       0.95      0.91      0.93        23
#    tigerlily       0.88      0.83      0.86        18
#        tulip       0.46      0.30      0.36        20
#   windflower       0.74      0.74      0.74        23
#
#     accuracy                           0.73       340
#    macro avg       0.74      0.73      0.72       340
# weighted avg       0.75      0.73      0.73       340
