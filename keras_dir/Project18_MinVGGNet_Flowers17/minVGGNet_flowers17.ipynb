# %%
# import the necessary packages
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from loader_util.preprocessing import ImageToArrayPreprocessor
from loader_util.preprocessing import AspectAwarePreprocessor
from loader_util.datasets import SimpleDatasetLoader
from loader_util.nn.conv import MinVGGNet
from tensorflow.keras.optimizers import SGD
from imutils import paths
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.axes._axes as axes
import os
sns.set()

# %%
# construct argument parser
dpath = r"C:\Users\mhasa\Google Drive\Tutorial Corner\PYTH\DeepLearning\DeepLearning-DL4CV\Edition3\PB_Code\datasets\flowers17\images"
args = {
    'dataset': dpath
}

print('[INFO] loading images ........')
imagePaths = list(paths.list_images(args['dataset']))
classNames = [pt.split(os.path.sep)[-2] for pt in imagePaths]
classNames = [str(x) for x in np.unique(classNames)]
# Out:
# [INFO] loading images ........

# %%
# initialise the preprocessors
aap = AspectAwarePreprocessor(64, 64)
iap = ImageToArrayPreprocessor()

# load the dataset from disk then scale pixels
sdl = SimpleDatasetLoader(preprocessors=[aap, iap])
data, labels = sdl.load(imagePaths, verbose=500)
data = data.astype('float') / 255.0
# Out:
# [INFO] processed 500/1360
# [INFO] processed 1000/1360

# %%
# partition data into train test splits
trainx, testx, trainy, testy = train_test_split(data, labels, 
                                                test_size=0.25,
                                                random_state=42)
# convert tthe labels from integers to vectors
le = LabelBinarizer()
trainy = le.fit_transform(trainy)
testy = le.transform(testy)

# %%
# initialise optimizer and compile model
print(('[INFO] compiling model ........'))
opt = SGD(learning_rate=0.05)
model = MinVGGNet.build(width=64, height=64, depth=3, classes=len(classNames))
model.compile(optimizer=opt, loss='categorical_crossentropy', 
              metrics=['accuracy'])
# train the network
H = model.fit(trainx, trainy, batch_size=32, validation_data=(testx, testy),
              epochs=100, verbose=1)
# Out:
# [INFO] compiling model ........
# Train on 1020 samples, validate on 340 samples
# Epoch 1/100
# 1020/1020 [==============================] - 16s 16ms/sample - loss: 3.1625 - accuracy: 0.2549 - val_loss: 2.5453 - val_accuracy: 0.1676
# Epoch 2/100
# 1020/1020 [==============================] - 2s 2ms/sample - loss: 1.9211 - accuracy: 0.4461 - val_loss: 2.9766 - val_accuracy: 0.1500
# Epoch 3/100
# 1020/1020 [==============================] - 2s 2ms/sample - loss: 1.4888 - accuracy: 0.5520 - val_loss: 2.8317 - val_accuracy: 0.2000
# Epoch 4/100
# 1020/1020 [==============================] - 2s 2ms/sample - loss: 1.0975 - accuracy: 0.6461 - val_loss: 2.8732 - val_accuracy: 0.2118
# Epoch 5/100
# 1020/1020 [==============================] - 2s 2ms/sample - loss: 0.7971 - accuracy: 0.7294 - val_loss: 2.3365 - val_accuracy: 0.3088
# Epoch 6/100
# 1020/1020 [==============================] - 2s 2ms/sample - loss: 0.6000 - accuracy: 0.8098 - val_loss: 2.2233 - val_accuracy: 0.3471
# Epoch 7/100
# 1020/1020 [==============================] - 2s 2ms/sample - loss: 0.4559 - accuracy: 0.8618 - val_loss: 2.0099 - val_accuracy: 0.4206
# Epoch 8/100
# 1020/1020 [==============================] - 2s 2ms/sample - loss: 0.2895 - accuracy: 0.9108 - val_loss: 1.9843 - val_accuracy: 0.4412
# Epoch 9/100
# 1020/1020 [==============================] - 2s 2ms/sample - loss: 0.2467 - accuracy: 0.9225 - val_loss: 1.8358 - val_accuracy: 0.5000
# Epoch 10/100
# 1020/1020 [==============================] - 2s 2ms/sample - loss: 0.1900 - accuracy: 0.9422 - val_loss: 1.7685 - val_accuracy: 0.5029
# Epoch 11/100
# 1020/1020 [==============================] - 2s 2ms/sample - loss: 0.1825 - accuracy: 0.9441 - val_loss: 1.9896 - val_accuracy: 0.4765
# Epoch 12/100
# 1020/1020 [==============================] - 2s 2ms/sample - loss: 0.1267 - accuracy: 0.9618 - val_loss: 1.7396 - val_accuracy: 0.5353
# Epoch 13/100
# 1020/1020 [==============================] - 2s 2ms/sample - loss: 0.0884 - accuracy: 0.9765 - val_loss: 1.7144 - val_accuracy: 0.5618
# Epoch 14/100
# 1020/1020 [==============================] - 2s 2ms/sample - loss: 0.0677 - accuracy: 0.9863 - val_loss: 1.6502 - val_accuracy: 0.5706
# Epoch 15/100
# 1020/1020 [==============================] - 2s 2ms/sample - loss: 0.0799 - accuracy: 0.9784 - val_loss: 1.8964 - val_accuracy: 0.5588
# Epoch 16/100
# 1020/1020 [==============================] - 2s 2ms/sample - loss: 0.0569 - accuracy: 0.9922 - val_loss: 1.6766 - val_accuracy: 0.5735
# Epoch 17/100
# 1020/1020 [==============================] - 2s 2ms/sample - loss: 0.0493 - accuracy: 0.9902 - val_loss: 1.6767 - val_accuracy: 0.5853
# Epoch 18/100
# 1020/1020 [==============================] - 2s 2ms/sample - loss: 0.0361 - accuracy: 0.9961 - val_loss: 1.6551 - val_accuracy: 0.6000
# Epoch 19/100
# 1020/1020 [==============================] - 2s 2ms/sample - loss: 0.0340 - accuracy: 0.9951 - val_loss: 1.7114 - val_accuracy: 0.5824
# Epoch 20/100
# 1020/1020 [==============================] - 2s 2ms/sample - loss: 0.0336 - accuracy: 0.9951 - val_loss: 1.7474 - val_accuracy: 0.5735
# Epoch 21/100
# 1020/1020 [==============================] - 2s 2ms/sample - loss: 0.0189 - accuracy: 1.0000 - val_loss: 1.7247 - val_accuracy: 0.6000
# Epoch 22/100
# 1020/1020 [==============================] - 2s 2ms/sample - loss: 0.0257 - accuracy: 0.9990 - val_loss: 1.7328 - val_accuracy: 0.5882
# Epoch 23/100
# 1020/1020 [==============================] - 2s 2ms/sample - loss: 0.0190 - accuracy: 0.9971 - val_loss: 1.7446 - val_accuracy: 0.6029
# Epoch 24/100
# 1020/1020 [==============================] - 2s 2ms/sample - loss: 0.0204 - accuracy: 0.9951 - val_loss: 1.7542 - val_accuracy: 0.5882
# Epoch 25/100
# 1020/1020 [==============================] - 2s 2ms/sample - loss: 0.0176 - accuracy: 0.9980 - val_loss: 1.7306 - val_accuracy: 0.6000
# Epoch 26/100
# 1020/1020 [==============================] - 2s 2ms/sample - loss: 0.0179 - accuracy: 0.9980 - val_loss: 1.8181 - val_accuracy: 0.5941
# Epoch 27/100
# 1020/1020 [==============================] - 2s 2ms/sample - loss: 0.0224 - accuracy: 0.9951 - val_loss: 1.7430 - val_accuracy: 0.6029
# Epoch 28/100
# 1020/1020 [==============================] - 2s 2ms/sample - loss: 0.0225 - accuracy: 0.9951 - val_loss: 1.8098 - val_accuracy: 0.5794
# Epoch 29/100
# 1020/1020 [==============================] - 2s 2ms/sample - loss: 0.0280 - accuracy: 0.9912 - val_loss: 1.7129 - val_accuracy: 0.5912
# Epoch 30/100
# 1020/1020 [==============================] - 2s 2ms/sample - loss: 0.0194 - accuracy: 0.9971 - val_loss: 1.7002 - val_accuracy: 0.6118
# Epoch 31/100
# 1020/1020 [==============================] - 2s 2ms/sample - loss: 0.0183 - accuracy: 0.9980 - val_loss: 1.7877 - val_accuracy: 0.6000
# Epoch 32/100
# 1020/1020 [==============================] - 2s 2ms/sample - loss: 0.0130 - accuracy: 0.9990 - val_loss: 1.7559 - val_accuracy: 0.6059
# Epoch 33/100
# 1020/1020 [==============================] - 2s 2ms/sample - loss: 0.0179 - accuracy: 0.9961 - val_loss: 1.8412 - val_accuracy: 0.5853
# Epoch 34/100
# 1020/1020 [==============================] - 2s 2ms/sample - loss: 0.0149 - accuracy: 0.9990 - val_loss: 1.7996 - val_accuracy: 0.5971
# Epoch 35/100
# 1020/1020 [==============================] - 2s 2ms/sample - loss: 0.0114 - accuracy: 0.9980 - val_loss: 1.8073 - val_accuracy: 0.5941
# Epoch 36/100
# 1020/1020 [==============================] - 2s 2ms/sample - loss: 0.0091 - accuracy: 1.0000 - val_loss: 1.7902 - val_accuracy: 0.6000
# Epoch 37/100
# 1020/1020 [==============================] - 2s 2ms/sample - loss: 0.0070 - accuracy: 1.0000 - val_loss: 1.7780 - val_accuracy: 0.5912
# Epoch 38/100
# 1020/1020 [==============================] - 2s 2ms/sample - loss: 0.0097 - accuracy: 1.0000 - val_loss: 1.8106 - val_accuracy: 0.5882
# Epoch 39/100
# 1020/1020 [==============================] - 2s 2ms/sample - loss: 0.0094 - accuracy: 0.9990 - val_loss: 1.8206 - val_accuracy: 0.6088
# Epoch 40/100
# 1020/1020 [==============================] - 2s 2ms/sample - loss: 0.0094 - accuracy: 0.9990 - val_loss: 1.7778 - val_accuracy: 0.5971
# Epoch 41/100
# 1020/1020 [==============================] - 2s 2ms/sample - loss: 0.0073 - accuracy: 0.9990 - val_loss: 1.7908 - val_accuracy: 0.5941
# Epoch 42/100
# 1020/1020 [==============================] - 2s 2ms/sample - loss: 0.0094 - accuracy: 0.9990 - val_loss: 1.8433 - val_accuracy: 0.5941
# Epoch 43/100
# 1020/1020 [==============================] - 2s 2ms/sample - loss: 0.0082 - accuracy: 0.9990 - val_loss: 1.8297 - val_accuracy: 0.5882
# Epoch 44/100
# 1020/1020 [==============================] - 2s 2ms/sample - loss: 0.0071 - accuracy: 0.9990 - val_loss: 1.8313 - val_accuracy: 0.5824
# Epoch 45/100
# 1020/1020 [==============================] - 2s 2ms/sample - loss: 0.0049 - accuracy: 1.0000 - val_loss: 1.8458 - val_accuracy: 0.5882
# Epoch 46/100
# 1020/1020 [==============================] - 2s 2ms/sample - loss: 0.0065 - accuracy: 1.0000 - val_loss: 1.8082 - val_accuracy: 0.5971
# Epoch 47/100
# 1020/1020 [==============================] - 2s 2ms/sample - loss: 0.0059 - accuracy: 1.0000 - val_loss: 1.8247 - val_accuracy: 0.5971
# Epoch 48/100
# 1020/1020 [==============================] - 2s 2ms/sample - loss: 0.0063 - accuracy: 0.9990 - val_loss: 1.8404 - val_accuracy: 0.5882
# Epoch 49/100
# 1020/1020 [==============================] - 2s 2ms/sample - loss: 0.0067 - accuracy: 0.9990 - val_loss: 1.8109 - val_accuracy: 0.6118
# Epoch 50/100
# 1020/1020 [==============================] - 2s 2ms/sample - loss: 0.0065 - accuracy: 0.9980 - val_loss: 1.8112 - val_accuracy: 0.5941
# Epoch 51/100
# 1020/1020 [==============================] - 2s 2ms/sample - loss: 0.0103 - accuracy: 0.9980 - val_loss: 1.7734 - val_accuracy: 0.6088
# Epoch 52/100
# 1020/1020 [==============================] - 2s 2ms/sample - loss: 0.0058 - accuracy: 1.0000 - val_loss: 1.7809 - val_accuracy: 0.6118
# Epoch 53/100
# 1020/1020 [==============================] - 2s 2ms/sample - loss: 0.0134 - accuracy: 0.9971 - val_loss: 1.8462 - val_accuracy: 0.6147
# Epoch 54/100
# 1020/1020 [==============================] - 2s 2ms/sample - loss: 0.0057 - accuracy: 1.0000 - val_loss: 1.8154 - val_accuracy: 0.6000
# Epoch 55/100
# 1020/1020 [==============================] - 2s 2ms/sample - loss: 0.0063 - accuracy: 1.0000 - val_loss: 1.8145 - val_accuracy: 0.5882
# Epoch 56/100
# 1020/1020 [==============================] - 2s 2ms/sample - loss: 0.0041 - accuracy: 1.0000 - val_loss: 1.8173 - val_accuracy: 0.6059
# Epoch 57/100
# 1020/1020 [==============================] - 2s 2ms/sample - loss: 0.0058 - accuracy: 0.9990 - val_loss: 2.1169 - val_accuracy: 0.5706
# Epoch 58/100
# 1020/1020 [==============================] - 2s 2ms/sample - loss: 0.0073 - accuracy: 0.9990 - val_loss: 1.9177 - val_accuracy: 0.6000
# Epoch 59/100
# 1020/1020 [==============================] - 2s 2ms/sample - loss: 0.0099 - accuracy: 0.9980 - val_loss: 2.0171 - val_accuracy: 0.5853
# Epoch 60/100
# 1020/1020 [==============================] - 2s 2ms/sample - loss: 0.0064 - accuracy: 1.0000 - val_loss: 1.8893 - val_accuracy: 0.5941
# Epoch 61/100
# 1020/1020 [==============================] - 2s 2ms/sample - loss: 0.0055 - accuracy: 1.0000 - val_loss: 1.9089 - val_accuracy: 0.5971
# Epoch 62/100
# 1020/1020 [==============================] - 2s 2ms/sample - loss: 0.0045 - accuracy: 1.0000 - val_loss: 1.9205 - val_accuracy: 0.5941
# Epoch 63/100
# 1020/1020 [==============================] - 2s 2ms/sample - loss: 0.0054 - accuracy: 1.0000 - val_loss: 1.8345 - val_accuracy: 0.6059
# Epoch 64/100
# 1020/1020 [==============================] - 2s 2ms/sample - loss: 0.0053 - accuracy: 1.0000 - val_loss: 1.7713 - val_accuracy: 0.6118
# Epoch 65/100
# 1020/1020 [==============================] - 2s 2ms/sample - loss: 0.0044 - accuracy: 1.0000 - val_loss: 1.7691 - val_accuracy: 0.6147
# Epoch 66/100
# 1020/1020 [==============================] - 2s 2ms/sample - loss: 0.0035 - accuracy: 1.0000 - val_loss: 1.7757 - val_accuracy: 0.6088
# Epoch 67/100
# 1020/1020 [==============================] - 2s 2ms/sample - loss: 0.0042 - accuracy: 1.0000 - val_loss: 1.7970 - val_accuracy: 0.6029
# Epoch 68/100
# 1020/1020 [==============================] - 2s 2ms/sample - loss: 0.0044 - accuracy: 1.0000 - val_loss: 1.8557 - val_accuracy: 0.6059
# Epoch 69/100
# 1020/1020 [==============================] - 2s 2ms/sample - loss: 0.0039 - accuracy: 1.0000 - val_loss: 1.7834 - val_accuracy: 0.6059
# Epoch 70/100
# 1020/1020 [==============================] - 2s 2ms/sample - loss: 0.0082 - accuracy: 0.9980 - val_loss: 1.8547 - val_accuracy: 0.5824
# Epoch 71/100
# 1020/1020 [==============================] - 2s 2ms/sample - loss: 0.0047 - accuracy: 1.0000 - val_loss: 1.7774 - val_accuracy: 0.6059
# Epoch 72/100
# 1020/1020 [==============================] - 2s 2ms/sample - loss: 0.0068 - accuracy: 0.9990 - val_loss: 1.8435 - val_accuracy: 0.6029
# Epoch 73/100
# 1020/1020 [==============================] - 2s 2ms/sample - loss: 0.0052 - accuracy: 1.0000 - val_loss: 1.7978 - val_accuracy: 0.6118
# Epoch 74/100
# 1020/1020 [==============================] - 2s 2ms/sample - loss: 0.0029 - accuracy: 1.0000 - val_loss: 1.7821 - val_accuracy: 0.6088
# Epoch 75/100
# 1020/1020 [==============================] - 2s 2ms/sample - loss: 0.0056 - accuracy: 0.9990 - val_loss: 1.8400 - val_accuracy: 0.6088
# Epoch 76/100
# 1020/1020 [==============================] - 2s 2ms/sample - loss: 0.0071 - accuracy: 0.9980 - val_loss: 1.8277 - val_accuracy: 0.6000
# Epoch 77/100
# 1020/1020 [==============================] - 2s 2ms/sample - loss: 0.0033 - accuracy: 1.0000 - val_loss: 1.8026 - val_accuracy: 0.6029
# Epoch 78/100
# 1020/1020 [==============================] - 2s 2ms/sample - loss: 0.0054 - accuracy: 0.9990 - val_loss: 1.7823 - val_accuracy: 0.6059
# Epoch 79/100
# 1020/1020 [==============================] - 2s 2ms/sample - loss: 0.0036 - accuracy: 1.0000 - val_loss: 1.8036 - val_accuracy: 0.6029
# Epoch 80/100
# 1020/1020 [==============================] - 2s 2ms/sample - loss: 0.0048 - accuracy: 1.0000 - val_loss: 1.8274 - val_accuracy: 0.5971
# Epoch 81/100
# 1020/1020 [==============================] - 2s 2ms/sample - loss: 0.0044 - accuracy: 0.9990 - val_loss: 1.8024 - val_accuracy: 0.6118
# Epoch 82/100
# 1020/1020 [==============================] - 2s 2ms/sample - loss: 0.0041 - accuracy: 1.0000 - val_loss: 1.8159 - val_accuracy: 0.6029
# Epoch 83/100
# 1020/1020 [==============================] - 2s 2ms/sample - loss: 0.0042 - accuracy: 0.9990 - val_loss: 1.8103 - val_accuracy: 0.6000
# Epoch 84/100
# 1020/1020 [==============================] - 2s 2ms/sample - loss: 0.0049 - accuracy: 0.9990 - val_loss: 1.9891 - val_accuracy: 0.5676
# Epoch 85/100
# 1020/1020 [==============================] - 2s 2ms/sample - loss: 0.0033 - accuracy: 1.0000 - val_loss: 1.9116 - val_accuracy: 0.5853
# Epoch 86/100
# 1020/1020 [==============================] - 2s 2ms/sample - loss: 0.0036 - accuracy: 1.0000 - val_loss: 1.9479 - val_accuracy: 0.5853
# Epoch 87/100
# 1020/1020 [==============================] - 2s 2ms/sample - loss: 0.0042 - accuracy: 0.9990 - val_loss: 1.8995 - val_accuracy: 0.5941
# Epoch 88/100
# 1020/1020 [==============================] - 2s 2ms/sample - loss: 0.0019 - accuracy: 1.0000 - val_loss: 1.8718 - val_accuracy: 0.6029
# Epoch 89/100
# 1020/1020 [==============================] - 2s 2ms/sample - loss: 0.0030 - accuracy: 1.0000 - val_loss: 1.8468 - val_accuracy: 0.5912
# Epoch 90/100
# 1020/1020 [==============================] - 2s 2ms/sample - loss: 0.0021 - accuracy: 1.0000 - val_loss: 1.8587 - val_accuracy: 0.5882
# Epoch 91/100
# 1020/1020 [==============================] - 2s 2ms/sample - loss: 0.0053 - accuracy: 0.9990 - val_loss: 1.8180 - val_accuracy: 0.5912
# Epoch 92/100
# 1020/1020 [==============================] - 2s 2ms/sample - loss: 0.0041 - accuracy: 0.9980 - val_loss: 1.8370 - val_accuracy: 0.5941
# Epoch 93/100
# 1020/1020 [==============================] - 2s 2ms/sample - loss: 0.0035 - accuracy: 0.9990 - val_loss: 1.8535 - val_accuracy: 0.5882
# Epoch 94/100
# 1020/1020 [==============================] - 2s 2ms/sample - loss: 0.0030 - accuracy: 1.0000 - val_loss: 1.8872 - val_accuracy: 0.5882
# Epoch 95/100
# 1020/1020 [==============================] - 2s 2ms/sample - loss: 0.0031 - accuracy: 1.0000 - val_loss: 1.8621 - val_accuracy: 0.5912
# Epoch 96/100
# 1020/1020 [==============================] - 2s 2ms/sample - loss: 0.0023 - accuracy: 1.0000 - val_loss: 1.8839 - val_accuracy: 0.5912
# Epoch 97/100
# 1020/1020 [==============================] - 2s 2ms/sample - loss: 0.0035 - accuracy: 1.0000 - val_loss: 1.8809 - val_accuracy: 0.5912
# Epoch 98/100
# 1020/1020 [==============================] - 2s 2ms/sample - loss: 0.0022 - accuracy: 1.0000 - val_loss: 1.9002 - val_accuracy: 0.5941
# Epoch 99/100
# 1020/1020 [==============================] - 2s 2ms/sample - loss: 0.0025 - accuracy: 1.0000 - val_loss: 1.8653 - val_accuracy: 0.5941
# Epoch 100/100
# 1020/1020 [==============================] - 2s 2ms/sample - loss: 0.0030 - accuracy: 1.0000 - val_loss: 1.9050 - val_accuracy: 0.5971

# %%
# evaluate the network
print ( "[INFO] evaluating network..." )
predictions = model.predict(testx, batch_size=32 )
print (classification_report(testy.argmax(axis=1 ),
predictions.argmax(axis=1 ), target_names=classNames))


# plot the performance
epochs = range(1,101)
loss = H.history['loss']
accuracy = H.history['accuracy']
val_loss = H.history['val_loss']
val_accuracy = H.history['val_accuracy']
plot_df = pd.DataFrame(data=np.c_[epochs,loss,accuracy,val_loss,val_accuracy], 
                       columns=['epochs','loss', 'accuracy', 'val_loss', 'val_accuracy'])

# do the actual plots
sns.set(font_scale=1)
f, ax = plt.subplots(1, 1, figsize=(15,8))
sns.lineplot(data=plot_df, x='epochs', y='loss', ax=ax, label='train loss', linewidth=3)
sns.lineplot(data=plot_df, x='epochs', y='accuracy', ax=ax, label='train accuracy', linewidth=3)
sns.lineplot(data=plot_df, x='epochs', y='val_loss', ax=ax, label='val loss', linewidth=3)
sns.lineplot(data=plot_df, x='epochs', y='val_accuracy', ax=ax, label='val_accuracy', linewidth=3)
ax.set_ylabel('Loss or Accuracy')
ax.set_xlabel('Epochs')
plt.setp(ax.get_legend().get_texts(), fontsize='18'); # for legend text
# Out:
# [INFO] evaluating network...
#               precision    recall  f1-score   support
#
#     bluebell       0.59      0.84      0.70        19
#    buttercup       0.47      0.53      0.50        15
#    coltsfoot       0.44      0.35      0.39        20
#      cowslip       0.68      0.57      0.62        23
#       crocus       0.44      0.58      0.50        19
#     daffodil       0.50      0.38      0.43        21
#        daisy       0.72      0.65      0.68        20
#    dandelion       0.60      0.67      0.63        27
#   fritillary       0.62      0.62      0.62        16
#         iris       0.62      0.65      0.63        20
#   lilyvalley       0.50      0.50      0.50        20
#        pansy       0.88      0.68      0.77        22
#     snowdrop       0.40      0.38      0.39        16
#    sunflower       0.81      0.94      0.87        18
#    tigerlily       0.59      0.72      0.65        18
#        tulip       0.44      0.30      0.36        23
#   windflower       0.75      0.78      0.77        23
#
#     accuracy                           0.60       340
#    macro avg       0.59      0.60      0.59       340
# weighted avg       0.60      0.60      0.59       340
